# %% [markdown]
# # Installing and Importing Dependencies

# %%
# !pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\programdata\anaconda3\lib\site-packages (0.9.1.0)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: absl-py in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (3.4.3)
# Requirement already satisfied: opencv-contrib-python in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (4.7.0.68)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (23.1.21)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (1.20.3)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->mediapipe) (1.16.0)

# %%
import mediapipe as mp
import cv2

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %% [markdown]
# # Making Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # Capturing Landmarks

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name ="Wakanda Forever"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Training Model using Scikit Learn

# %%
#READ IN COLLECTED DATA AND PROCESS



import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df[df['class']=='Happy']
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 62   Happy  0.538579  0.474900 -0.962196  0.999692  0.558504  0.410773
# 63   Happy  0.537344  0.474742 -0.994649  0.999692  0.558224  0.410546
# 64   Happy  0.535941  0.474718 -1.002222  0.999694  0.557572  0.410534
# 65   Happy  0.535315  0.474813 -1.014505  0.999697  0.557167  0.410611
# 66   Happy  0.534656  0.474841 -1.031607  0.999695  0.556735  0.410719
# ..     ...       ...       ...       ...       ...       ...       ...
# 244  Happy  0.515682  0.468049 -1.041435  0.999880  0.541497  0.406743
# 245  Happy  0.515548  0.462649 -1.060309  0.999872  0.540909  0.402382
# 246  Happy  0.515444  0.459799 -1.066448  0.999869  0.540442  0.399979
# 247  Happy  0.515416  0.460147 -1.063301  0.999869  0.540333  0.399913
# 248  Happy  0.515322  0.456651 -1.071306  0.999854  0.539943  0.397012
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 62  -0.906628  0.999469  0.572301  ... -0.002866   0.0  0.580355  0.412897
# 63  -0.934199  0.999466  0.572353  ... -0.004240   0.0  0.576636  0.412644
# 64  -0.942999  0.999466  0.572330  ... -0.004026   0.0  0.572230  0.413393
# 65  -0.955635  0.999466  0.572306  ... -0.004025   0.0  0.572532  0.414824
# 66  -0.972341  0.999459  0.572258  ... -0.003905   0.0  0.572738  0.414580
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 244 -0.985479  0.999767  0.558266  ... -0.001385   0.0  0.562587  0.404568
# 245 -1.002765  0.999744  0.557591  ... -0.002682   0.0  0.560714  0.403640
# 246 -1.008020  0.999734  0.557064  ... -0.002718   0.0  0.561200  0.403499
# 247 -1.004545  0.999737  0.556908  ... -0.002573   0.0  0.558938  0.407737
# 248 -1.010130  0.999707  0.556446  ... -0.001406   0.0  0.559121  0.403309
#
#          z500  v500      x501      y501      z501  v501
# 62   0.014937   0.0  0.584400  0.408888  0.015654   0.0
# 63   0.012230   0.0  0.580697  0.408248  0.012847   0.0
# 64   0.012580   0.0  0.576263  0.409153  0.013223   0.0
# 65   0.012902   0.0  0.576533  0.410474  0.013534   0.0
# 66   0.013269   0.0  0.576720  0.410398  0.013921   0.0
# ..        ...   ...       ...       ...       ...   ...
# 244  0.017762   0.0  0.566791  0.399394  0.018711   0.0
# 245  0.016120   0.0  0.564887  0.398438  0.017023   0.0
# 246  0.015766   0.0  0.565326  0.398210  0.016659   0.0
# 247  0.017288   0.0  0.563042  0.403752  0.018114   0.0
# 248  0.017933   0.0  0.563430  0.398335  0.018903   0.0
#
# [187 rows x 2005 columns]

# %%
df[df['class']=='Sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 249   Sad  0.557780  0.465226 -0.766937  0.999963  0.581325  0.408964
# 250   Sad  0.557904  0.469515 -0.973653  0.999949  0.581470  0.409956
# 251   Sad  0.557965  0.473043 -0.951075  0.999941  0.581551  0.411320
# 252   Sad  0.557970  0.474831 -0.952698  0.999935  0.581559  0.412431
# 253   Sad  0.558029  0.475937 -0.931496  0.999931  0.581629  0.413133
# ..    ...       ...       ...       ...       ...       ...       ...
# 611   Sad  0.566496  0.453620 -1.023911  0.999833  0.589508  0.393151
# 612   Sad  0.562868  0.451987 -1.032680  0.999827  0.586930  0.392346
# 613   Sad  0.556279  0.449434 -0.840729  0.999835  0.582004  0.391046
# 614   Sad  0.553888  0.448762 -0.868398  0.999841  0.580119  0.390496
# 615   Sad  0.553401  0.448254 -0.881780  0.999846  0.579028  0.389996
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 249 -0.720094  0.999917  0.596745  ... -0.002452   0.0  0.608681  0.420644
# 250 -0.924302  0.999892  0.597218  ... -0.001667   0.0  0.608547  0.422931
# 251 -0.902500  0.999878  0.597551  ... -0.001673   0.0  0.608027  0.421811
# 252 -0.904211  0.999866  0.597677  ... -0.002259   0.0  0.607454  0.421564
# 253 -0.883085  0.999856  0.597888  ... -0.002199   0.0  0.608087  0.421704
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 611 -0.963450  0.999627  0.605301  ...  0.002233   0.0  0.607183  0.404276
# 612 -0.973534  0.999614  0.603501  ...  0.002336   0.0  0.607577  0.405754
# 613 -0.788799  0.999632  0.600062  ...  0.002029   0.0  0.604272  0.400878
# 614 -0.801576  0.999641  0.598482  ...  0.001744   0.0  0.605620  0.401609
# 615 -0.823998  0.999650  0.597379  ...  0.001229   0.0  0.603823  0.400433
#
#          z500  v500      x501      y501      z501  v501
# 249  0.014538   0.0  0.612374  0.416477  0.015024   0.0
# 250  0.015164   0.0  0.612339  0.418314  0.015677   0.0
# 251  0.015497   0.0  0.611776  0.417492  0.015974   0.0
# 252  0.014900   0.0  0.611195  0.417429  0.015333   0.0
# 253  0.014856   0.0  0.611865  0.417535  0.015292   0.0
# ..        ...   ...       ...       ...       ...   ...
# 611  0.021010   0.0  0.611194  0.399333  0.021844   0.0
# 612  0.021205   0.0  0.611660  0.400457  0.022079   0.0
# 613  0.019882   0.0  0.608400  0.395769  0.020703   0.0
# 614  0.020241   0.0  0.609760  0.396526  0.021005   0.0
# 615  0.019949   0.0  0.607858  0.395700  0.020698   0.0
#
# [367 rows x 2005 columns]

# %%
df[df['class']=='Victorious']
# Out:
#           class        x1        y1        z1        v1        x2        y2  \
# 616  Victorious  0.566288  0.457995 -1.240355  0.999988  0.589322  0.394950
# 617  Victorious  0.566297  0.458259 -1.146277  0.999989  0.589121  0.395486
# 618  Victorious  0.566306  0.458464 -0.898226  0.999989  0.589093  0.396075
# 619  Victorious  0.567467  0.459874 -1.041126  0.999990  0.589437  0.396922
# 620  Victorious  0.569435  0.460362 -1.170906  0.999990  0.590083  0.397092
# ..          ...       ...       ...       ...       ...       ...       ...
# 882  Victorious  0.530750  0.448619 -0.995988  0.999996  0.554484  0.392161
# 883  Victorious  0.532321  0.448598 -0.941832  0.999990  0.554715  0.391456
# 884  Victorious  0.535627  0.447883 -1.056893  0.999983  0.555787  0.390101
# 885  Victorious  0.535621  0.443714 -1.068531  0.999981  0.555791  0.382075
# 886  Victorious  0.534934  0.433736 -0.976989  0.999980  0.555683  0.372962
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 616 -1.175953  0.999984  0.602704  ... -0.000999   0.0  0.606563  0.400426
# 617 -1.084761  0.999985  0.602497  ... -0.001232   0.0  0.608521  0.401112
# 618 -0.838397  0.999985  0.602497  ... -0.001980   0.0  0.611350  0.402496
# 619 -0.978118  0.999986  0.603191  ... -0.001717   0.0  0.613918  0.403476
# 620 -1.109650  0.999987  0.604125  ... -0.001595   0.0  0.613327  0.403535
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 882 -0.952260  0.999995  0.569397  ... -0.002795   0.0  0.577492  0.395128
# 883 -0.889307  0.999984  0.569490  ... -0.002700   0.0  0.577073  0.392258
# 884 -0.986660  0.999974  0.570155  ... -0.002788   0.0  0.577330  0.392147
# 885 -1.013761  0.999964  0.569980  ... -0.000523   0.0  0.575156  0.383777
# 886 -0.923890  0.999962  0.569764  ... -0.000463   0.0  0.574195  0.376508
#
#          z500  v500      x501      y501      z501  v501
# 616  0.017715   0.0  0.610044  0.396991  0.018335   0.0
# 617  0.017679   0.0  0.612002  0.397914  0.018265   0.0
# 618  0.017225   0.0  0.614837  0.399460  0.017793   0.0
# 619  0.017439   0.0  0.617413  0.400475  0.017994   0.0
# 620  0.017862   0.0  0.616684  0.400676  0.018464   0.0
# ..        ...   ...       ...       ...       ...   ...
# 882  0.014824   0.0  0.581268  0.390753  0.015573   0.0
# 883  0.015445   0.0  0.580762  0.387931  0.016237   0.0
# 884  0.015125   0.0  0.581044  0.388120  0.015866   0.0
# 885  0.017505   0.0  0.579067  0.379386  0.018340   0.0
# 886  0.018349   0.0  0.577957  0.372093  0.019249   0.0
#
# [271 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 533           Sad
# 415           Sad
# 181         Happy
# 831    Victorious
# 646    Victorious
#           ...
# 204         Happy
# 205         Happy
# 92          Happy
# 226         Happy
# 94          Happy
# Name: class, Length: 357, dtype: object

# %%
#TRAINING OF ML CLASSIFICATION MODEL

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Sad', 'Sad', 'Happy', 'Victorious', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Happy', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Sad', 'Victorious', 'Victorious',
#        'Sad', 'Happy', 'Victorious', 'Victorious', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Sad', 'Victorious', 'Wakanda Forever', 'Wakanda Forever',
#        'Sad', 'Wakanda Forever', 'Sad', 'Sad', 'Wakanda Forever', 'Sad',
#        'Wakanda Forever', 'Sad', 'Happy', 'Happy', 'Sad',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Wakanda Forever', 'Victorious',
#        'Wakanda Forever', 'Wakanda Forever', 'Sad', 'Sad', 'Sad',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Sad', 'Sad', 'Victorious',
#        'Sad', 'Wakanda Forever', 'Sad', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Happy', 'Sad', 'Sad', 'Victorious',
#        'Happy', 'Sad', 'Happy', 'Happy', 'Victorious', 'Victorious',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Victorious', 'Sad', 'Sad', 'Happy', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Wakanda Forever',
#        'Victorious', 'Happy', 'Victorious', 'Victorious',
#        'Wakanda Forever', 'Happy', 'Happy', 'Happy', 'Victorious',
#        'Victorious', 'Sad', 'Victorious', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Wakanda Forever', 'Wakanda Forever', 'Victorious', 'Sad', 'Sad',
#        'Sad', 'Victorious', 'Wakanda Forever', 'Sad', 'Sad', 'Victorious',
#        'Victorious', 'Wakanda Forever', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Sad', 'Sad', 'Victorious',
#        'Victorious', 'Sad', 'Sad', 'Wakanda Forever', 'Happy',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Sad', 'Happy', 'Sad',
#        'Sad', 'Happy', 'Victorious', 'Sad', 'Wakanda Forever', 'Happy',
#        'Sad', 'Victorious', 'Wakanda Forever', 'Wakanda Forever', 'Happy',
#        'Happy', 'Victorious', 'Wakanda Forever', 'Sad', 'Victorious',
#        'Sad', 'Happy', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Victorious', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Sad', 'Happy',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Sad', 'Victorious',
#        'Sad', 'Victorious', 'Victorious', 'Wakanda Forever', 'Sad', 'Sad',
#        'Victorious', 'Wakanda Forever', 'Happy', 'Wakanda Forever',
#        'Victorious', 'Wakanda Forever', 'Happy', 'Victorious', 'Sad',
#        'Happy', 'Victorious', 'Wakanda Forever', 'Victorious', 'Happy',
#        'Happy', 'Happy', 'Victorious', 'Sad', 'Wakanda Forever',
#        'Victorious', 'Victorious', 'Victorious', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Wakanda Forever', 'Victorious', 'Wakanda Forever', 'Happy',
#        'Happy', 'Victorious', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Victorious', 'Sad', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Wakanda Forever',
#        'Victorious', 'Wakanda Forever', 'Victorious', 'Happy',
#        'Wakanda Forever', 'Happy', 'Victorious', 'Sad', 'Sad',
#        'Victorious', 'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Happy',
#        'Victorious', 'Victorious', 'Sad', 'Wakanda Forever', 'Happy',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Victorious', 'Victorious', 'Sad', 'Happy', 'Sad', 'Victorious',
#        'Victorious', 'Sad', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Happy', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Victorious', 'Victorious',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Happy', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Wakanda Forever', 'Happy', 'Sad',
#        'Sad', 'Victorious', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Victorious', 'Sad', 'Sad',
#        'Happy', 'Wakanda Forever', 'Sad', 'Victorious', 'Victorious',
#        'Sad', 'Sad', 'Happy', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Wakanda Forever', 'Sad', 'Sad', 'Sad',
#        'Happy', 'Sad', 'Wakanda Forever', 'Victorious', 'Wakanda Forever',
#        'Sad', 'Sad', 'Wakanda Forever', 'Sad', 'Sad', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Happy', 'Sad', 'Victorious',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Happy',
#        'Wakanda Forever', 'Wakanda Forever', 'Sad', 'Victorious', 'Happy',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy'],
#       dtype='<U15')

# %%
#EVALUATE AND SERIALIZE MODEL



from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Sad', 'Sad', 'Happy', 'Victorious', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Happy', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Sad', 'Victorious', 'Victorious',
#        'Sad', 'Happy', 'Victorious', 'Victorious', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Sad', 'Victorious', 'Wakanda Forever', 'Wakanda Forever',
#        'Sad', 'Wakanda Forever', 'Sad', 'Sad', 'Wakanda Forever', 'Sad',
#        'Wakanda Forever', 'Sad', 'Happy', 'Happy', 'Sad',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Wakanda Forever', 'Victorious',
#        'Wakanda Forever', 'Wakanda Forever', 'Sad', 'Sad', 'Sad',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Sad', 'Sad', 'Victorious',
#        'Sad', 'Wakanda Forever', 'Sad', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Happy', 'Sad', 'Sad', 'Victorious',
#        'Happy', 'Sad', 'Happy', 'Happy', 'Victorious', 'Victorious',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Victorious', 'Sad', 'Sad', 'Happy', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Wakanda Forever',
#        'Victorious', 'Happy', 'Victorious', 'Victorious',
#        'Wakanda Forever', 'Happy', 'Happy', 'Happy', 'Victorious',
#        'Victorious', 'Sad', 'Victorious', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Wakanda Forever', 'Wakanda Forever', 'Victorious', 'Sad', 'Sad',
#        'Sad', 'Victorious', 'Wakanda Forever', 'Sad', 'Sad', 'Victorious',
#        'Victorious', 'Wakanda Forever', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Sad', 'Sad', 'Victorious',
#        'Victorious', 'Sad', 'Sad', 'Wakanda Forever', 'Happy',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Sad', 'Happy', 'Sad',
#        'Sad', 'Happy', 'Victorious', 'Sad', 'Wakanda Forever', 'Happy',
#        'Sad', 'Victorious', 'Wakanda Forever', 'Wakanda Forever', 'Happy',
#        'Happy', 'Victorious', 'Wakanda Forever', 'Sad', 'Victorious',
#        'Sad', 'Happy', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Victorious', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Sad', 'Happy',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Sad', 'Victorious',
#        'Sad', 'Victorious', 'Victorious', 'Wakanda Forever', 'Sad', 'Sad',
#        'Victorious', 'Wakanda Forever', 'Happy', 'Wakanda Forever',
#        'Victorious', 'Wakanda Forever', 'Happy', 'Victorious', 'Sad',
#        'Happy', 'Victorious', 'Wakanda Forever', 'Victorious', 'Happy',
#        'Happy', 'Happy', 'Victorious', 'Sad', 'Wakanda Forever',
#        'Victorious', 'Victorious', 'Victorious', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Wakanda Forever', 'Victorious', 'Wakanda Forever', 'Happy',
#        'Happy', 'Victorious', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Victorious', 'Sad', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Wakanda Forever',
#        'Victorious', 'Wakanda Forever', 'Victorious', 'Happy',
#        'Wakanda Forever', 'Happy', 'Victorious', 'Sad', 'Sad',
#        'Victorious', 'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Happy',
#        'Victorious', 'Victorious', 'Sad', 'Wakanda Forever', 'Happy',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Victorious', 'Sad',
#        'Victorious', 'Victorious', 'Sad', 'Happy', 'Sad', 'Victorious',
#        'Victorious', 'Sad', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Wakanda Forever', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Happy', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Victorious', 'Victorious',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Happy', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Wakanda Forever', 'Happy', 'Sad',
#        'Sad', 'Victorious', 'Sad', 'Wakanda Forever', 'Wakanda Forever',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Victorious', 'Sad',
#        'Wakanda Forever', 'Victorious', 'Victorious', 'Sad', 'Sad',
#        'Happy', 'Wakanda Forever', 'Sad', 'Victorious', 'Victorious',
#        'Sad', 'Sad', 'Happy', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Wakanda Forever', 'Sad', 'Sad', 'Sad',
#        'Happy', 'Sad', 'Wakanda Forever', 'Victorious', 'Wakanda Forever',
#        'Sad', 'Sad', 'Wakanda Forever', 'Sad', 'Sad', 'Wakanda Forever',
#        'Wakanda Forever', 'Wakanda Forever', 'Happy', 'Sad', 'Victorious',
#        'Wakanda Forever', 'Sad', 'Wakanda Forever', 'Happy',
#        'Wakanda Forever', 'Wakanda Forever', 'Sad', 'Victorious', 'Happy',
#        'Wakanda Forever', 'Sad', 'Victorious', 'Wakanda Forever',
#        'Wakanda Forever', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy'],
#       dtype=object)

# %%
y_test
# Out:
# 533           Sad
# 415           Sad
# 181         Happy
# 831    Victorious
# 646    Victorious
#           ...
# 204         Happy
# 205         Happy
# 92          Happy
# 226         Happy
# 94          Happy
# Name: class, Length: 357, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # Making detection with model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [1280,720]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Wakanda Forever [0.19 0.03 0.   0.78]
# Wakanda Forever [0.2  0.06 0.   0.74]
# Wakanda Forever [0.17 0.06 0.   0.77]
# Wakanda Forever [0.19 0.07 0.   0.74]
# Wakanda Forever [0.3  0.14 0.   0.56]
# Wakanda Forever [0.31 0.22 0.   0.47]
# Happy [0.42 0.41 0.   0.17]
# Sad [0.41 0.44 0.01 0.14]
# Sad [0.42 0.45 0.   0.13]
# Sad [0.42 0.45 0.01 0.12]
# Sad [0.42 0.46 0.01 0.11]
# Sad [0.43 0.46 0.01 0.1 ]
# Sad [0.43 0.47 0.01 0.09]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.4  0.5  0.01 0.09]
# Sad [0.42 0.48 0.01 0.09]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.4  0.5  0.01 0.09]
# Sad [0.42 0.49 0.01 0.08]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.41 0.44 0.   0.15]
# Sad [0.42 0.43 0.   0.15]
# Sad [0.42 0.45 0.   0.13]
# Happy [0.43 0.43 0.01 0.13]
# Sad [0.41 0.47 0.   0.12]
# Sad [0.42 0.43 0.   0.15]
# Happy [0.43 0.41 0.   0.16]
# Happy [0.42 0.41 0.   0.17]
# Happy [0.42 0.41 0.   0.17]
# Happy [0.43 0.41 0.   0.16]
# Sad [0.41 0.44 0.   0.15]
# Sad [0.42 0.43 0.01 0.14]
# Sad [0.43 0.44 0.01 0.12]
# Happy [0.42 0.42 0.   0.16]
# Sad [0.41 0.44 0.   0.15]
# Sad [0.41 0.46 0.01 0.12]
# Sad [0.41 0.45 0.01 0.13]
# Sad [0.41 0.45 0.   0.14]
# Sad [0.4  0.48 0.01 0.11]
# Sad [0.42 0.47 0.01 0.1 ]
# Sad [0.4  0.48 0.01 0.11]
# Sad [0.44 0.46 0.01 0.09]
# Happy [0.49 0.39 0.01 0.11]
# Happy [0.49 0.36 0.01 0.14]
# Happy [0.47 0.37 0.01 0.15]
# Happy [0.48 0.37 0.01 0.14]
# Happy [0.49 0.36 0.01 0.14]
# Happy [0.47 0.38 0.01 0.14]
# Happy [0.48 0.38 0.01 0.13]
# Happy [0.49 0.37 0.01 0.13]
# Happy [0.49 0.37 0.01 0.13]
# Happy [0.49 0.37 0.01 0.13]
# Happy [0.49 0.37 0.01 0.13]
# Happy [0.49 0.38 0.01 0.12]
# Happy [0.49 0.38 0.01 0.12]
# Happy [0.48 0.39 0.01 0.12]
# Happy [0.49 0.38 0.01 0.12]
# Happy [0.49 0.38 0.01 0.12]
# Happy [0.49 0.38 0.01 0.12]
# Sad [0.43 0.46 0.01 0.1 ]
# Sad [0.43 0.47 0.01 0.09]
# Sad [0.42 0.49 0.01 0.08]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.42 0.48 0.01 0.09]
# Happy [0.49 0.41 0.01 0.09]
# Happy [0.47 0.37 0.01 0.15]
# Happy [0.49 0.37 0.01 0.13]
# Happy [0.47 0.4  0.01 0.12]
# Happy [0.48 0.38 0.01 0.13]
# Happy [0.49 0.37 0.01 0.13]
# Happy [0.46 0.39 0.01 0.14]
# Happy [0.46 0.39 0.01 0.14]
# Sad [0.42 0.47 0.01 0.1 ]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.38 0.53 0.01 0.08]
# Sad [0.38 0.53 0.01 0.08]
# Happy [0.45 0.41 0.01 0.13]
# Happy [0.45 0.4  0.01 0.14]
# Happy [0.45 0.4  0.01 0.14]
# Happy [0.45 0.4  0.01 0.14]
# Happy [0.46 0.4  0.01 0.13]
# Happy [0.45 0.4  0.01 0.14]
# Happy [0.45 0.41 0.01 0.13]
# Happy [0.46 0.39 0.01 0.14]
# Happy [0.46 0.42 0.01 0.11]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.34 0.56 0.01 0.09]
# Sad [0.3  0.44 0.04 0.22]
# Sad [0.19 0.35 0.14 0.32]
# Sad [0.17 0.35 0.13 0.35]
# Wakanda Forever [0.22 0.29 0.11 0.38]
# Wakanda Forever [0.23 0.36 0.02 0.39]
# Sad [0.21 0.39 0.02 0.38]
# Sad [0.22 0.39 0.02 0.37]
# Wakanda Forever [0.23 0.37 0.02 0.38]
# Wakanda Forever [0.23 0.37 0.02 0.38]
# Wakanda Forever [0.23 0.35 0.05 0.37]
# Wakanda Forever [0.23 0.34 0.06 0.37]
# Wakanda Forever [0.22 0.36 0.05 0.37]
# Wakanda Forever [0.23 0.35 0.05 0.37]
# Wakanda Forever [0.22 0.36 0.05 0.37]
# Wakanda Forever [0.23 0.35 0.05 0.37]
# Wakanda Forever [0.22 0.32 0.13 0.33]
# Wakanda Forever [0.24 0.31 0.11 0.34]
# Wakanda Forever [0.22 0.31 0.05 0.42]
# Wakanda Forever [0.17 0.34 0.02 0.47]
# Sad [0.14 0.46 0.04 0.36]
# Sad [0.23 0.49 0.04 0.24]
# Sad [0.29 0.42 0.05 0.24]
# Sad [0.28 0.46 0.02 0.24]
# Sad [0.29 0.47 0.01 0.23]
# Sad [0.28 0.49 0.   0.23]
# Sad [0.23 0.44 0.01 0.32]
# Sad [0.24 0.49 0.01 0.26]
# Sad [0.23 0.44 0.   0.33]
# Sad [0.28 0.4  0.   0.32]
# Sad [0.23 0.45 0.   0.32]
# Sad [0.2  0.47 0.   0.33]
# Sad [0.19 0.46 0.   0.35]
# Sad [0.16 0.46 0.   0.38]
# Wakanda Forever [0.07 0.26 0.01 0.66]
# Wakanda Forever [0.14 0.31 0.02 0.53]
# Sad [0.35 0.38 0.04 0.23]
# Wakanda Forever [0.16 0.23 0.08 0.53]
# Wakanda Forever [0.11 0.24 0.08 0.57]
# Wakanda Forever [0.03 0.11 0.09 0.77]
# Wakanda Forever [0.03 0.07 0.06 0.84]
# Wakanda Forever [0.04 0.07 0.06 0.83]
# Wakanda Forever [0.04 0.04 0.04 0.88]
# Wakanda Forever [0.04 0.07 0.05 0.84]
# Wakanda Forever [0.05 0.07 0.05 0.83]
# Wakanda Forever [0.08 0.1  0.08 0.74]
# Wakanda Forever [0.1  0.12 0.08 0.7 ]
# Wakanda Forever [0.1  0.13 0.09 0.68]
# Wakanda Forever [0.11 0.14 0.09 0.66]
# Wakanda Forever [0.11 0.14 0.08 0.67]
# Wakanda Forever [0.11 0.16 0.17 0.56]
# Wakanda Forever [0.16 0.16 0.14 0.54]
# Wakanda Forever [0.18 0.15 0.14 0.53]
# Wakanda Forever [0.27 0.13 0.14 0.46]
# Wakanda Forever [0.25 0.16 0.14 0.45]
# Wakanda Forever [0.3  0.24 0.14 0.32]
# Wakanda Forever [0.21 0.3  0.14 0.35]
# Wakanda Forever [0.24 0.33 0.03 0.4 ]
# Wakanda Forever [0.24 0.28 0.07 0.41]
# Wakanda Forever [0.25 0.28 0.06 0.41]
# Wakanda Forever [0.18 0.29 0.05 0.48]
# Wakanda Forever [0.14 0.33 0.05 0.48]
# Wakanda Forever [0.15 0.28 0.05 0.52]
# Wakanda Forever [0.15 0.22 0.05 0.58]
# Wakanda Forever [0.17 0.24 0.05 0.54]
# Wakanda Forever [0.17 0.22 0.04 0.57]
# Wakanda Forever [0.15 0.25 0.04 0.56]
# Wakanda Forever [0.15 0.26 0.04 0.55]
# Wakanda Forever [0.16 0.24 0.04 0.56]
# Wakanda Forever [0.16 0.22 0.04 0.58]
# Wakanda Forever [0.17 0.22 0.04 0.57]
# Wakanda Forever [0.16 0.24 0.04 0.56]
# Wakanda Forever [0.17 0.31 0.05 0.47]
# Wakanda Forever [0.15 0.25 0.18 0.42]
# Wakanda Forever [0.17 0.14 0.12 0.57]
# Wakanda Forever [0.16 0.19 0.18 0.47]
# Wakanda Forever [0.15 0.22 0.18 0.45]
# Wakanda Forever [0.16 0.22 0.18 0.44]
# Wakanda Forever [0.15 0.21 0.18 0.46]
# Wakanda Forever [0.13 0.19 0.18 0.5 ]
# Wakanda Forever [0.12 0.19 0.18 0.51]
# Wakanda Forever [0.11 0.21 0.19 0.49]
# Wakanda Forever [0.09 0.21 0.22 0.48]
# Wakanda Forever [0.09 0.2  0.27 0.44]
# Wakanda Forever [0.08 0.18 0.34 0.4 ]
# Wakanda Forever [0.08 0.18 0.34 0.4 ]
# Wakanda Forever [0.08 0.18 0.35 0.39]
# Victorious [0.09 0.19 0.36 0.36]
# Victorious [0.09 0.18 0.37 0.36]
# Victorious [0.09 0.19 0.37 0.35]
# Victorious [0.09 0.19 0.37 0.35]
# Victorious [0.09 0.17 0.38 0.36]
# Victorious [0.09 0.16 0.38 0.37]
# Victorious [0.09 0.17 0.39 0.35]
# Victorious [0.09 0.17 0.39 0.35]
# Victorious [0.09 0.15 0.43 0.33]
# Victorious [0.09 0.16 0.45 0.3 ]
# Victorious [0.09 0.16 0.47 0.28]
# Victorious [0.08 0.15 0.5  0.27]
# Victorious [0.08 0.15 0.51 0.26]
# Victorious [0.08 0.13 0.55 0.24]
# Victorious [0.08 0.15 0.56 0.21]
# Victorious [0.07 0.14 0.57 0.22]
# Victorious [0.06 0.1  0.59 0.25]
# Victorious [0.07 0.12 0.59 0.22]
# Victorious [0.11 0.19 0.4  0.3 ]
# Wakanda Forever [0.15 0.27 0.17 0.41]
# Happy [0.33 0.32 0.07 0.28]
# Happy [0.32 0.31 0.06 0.31]
# Happy [0.35 0.3  0.04 0.31]
# Happy [0.34 0.32 0.04 0.3 ]
# Sad [0.3  0.34 0.04 0.32]
# Happy [0.34 0.31 0.01 0.34]
# Wakanda Forever [0.3  0.34 0.01 0.35]
# Wakanda Forever [0.31 0.31 0.01 0.37]
# Wakanda Forever [0.31 0.3  0.01 0.38]
# Wakanda Forever [0.31 0.3  0.01 0.38]
# Wakanda Forever [0.31 0.31 0.01 0.37]
# Wakanda Forever [0.32 0.3  0.01 0.37]
# Wakanda Forever [0.31 0.3  0.01 0.38]
# Wakanda Forever [0.32 0.29 0.01 0.38]
# Sad [0.26 0.38 0.01 0.35]
# Sad [0.29 0.36 0.01 0.34]
# Wakanda Forever [0.3  0.34 0.01 0.35]
# Wakanda Forever [0.3  0.34 0.01 0.35]
# Happy [0.34 0.31 0.01 0.34]
# Wakanda Forever [0.32 0.32 0.01 0.35]
# Happy [0.34 0.31 0.01 0.34]
# Wakanda Forever [0.33 0.3  0.01 0.36]
# Wakanda Forever [0.34 0.29 0.01 0.36]
# Wakanda Forever [0.33 0.28 0.01 0.38]
# Wakanda Forever [0.33 0.29 0.01 0.37]
# Wakanda Forever [0.33 0.3  0.01 0.36]
# Wakanda Forever [0.32 0.3  0.01 0.37]
# Wakanda Forever [0.31 0.3  0.01 0.38]
# Wakanda Forever [0.34 0.28 0.01 0.37]
# Wakanda Forever [0.3  0.33 0.01 0.36]
# Wakanda Forever [0.3  0.33 0.01 0.36]
# Wakanda Forever [0.28 0.33 0.01 0.38]
# Wakanda Forever [0.25 0.35 0.   0.4 ]
# Wakanda Forever [0.27 0.3  0.   0.43]
# Wakanda Forever [0.28 0.27 0.   0.45]
# Wakanda Forever [0.16 0.27 0.   0.57]
# Wakanda Forever [0.14 0.23 0.   0.63]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.11 0.22 0.   0.67]
# Wakanda Forever [0.11 0.22 0.   0.67]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.11 0.23 0.   0.66]
# Wakanda Forever [0.11 0.22 0.   0.67]
# Wakanda Forever [0.12 0.2  0.   0.68]
# Wakanda Forever [0.11 0.2  0.   0.69]
# Wakanda Forever [0.1 0.2 0.  0.7]
# Wakanda Forever [0.11 0.19 0.   0.7 ]
# Wakanda Forever [0.11 0.22 0.   0.67]
# Wakanda Forever [0.11 0.21 0.   0.68]
# Wakanda Forever [0.1  0.19 0.   0.71]
# Wakanda Forever [0.1  0.22 0.   0.68]
# Wakanda Forever [0.11 0.21 0.   0.68]
# Wakanda Forever [0.11 0.16 0.   0.73]
# Wakanda Forever [0.12 0.19 0.   0.69]
# Wakanda Forever [0.14 0.11 0.   0.75]
# Wakanda Forever [0.15 0.1  0.   0.75]
# Wakanda Forever [0.15 0.13 0.   0.72]
# Wakanda Forever [0.15 0.11 0.   0.74]
# Wakanda Forever [0.14 0.08 0.   0.78]
# Wakanda Forever [0.23 0.21 0.   0.56]
# Wakanda Forever [0.29 0.24 0.   0.47]
# Wakanda Forever [0.1  0.23 0.01 0.66]
# Wakanda Forever [0.09 0.19 0.1  0.62]
# Wakanda Forever [0.13 0.21 0.03 0.63]
# Wakanda Forever [0.09 0.15 0.01 0.75]
# Wakanda Forever [0.09 0.18 0.01 0.72]
# Wakanda Forever [0.1  0.18 0.01 0.71]
# Wakanda Forever [0.09 0.19 0.01 0.71]
# Wakanda Forever [0.11 0.21 0.01 0.67]
# Wakanda Forever [0.13 0.2  0.03 0.64]
# Wakanda Forever [0.16 0.19 0.04 0.61]
# Wakanda Forever [0.17 0.17 0.04 0.62]
# Wakanda Forever [0.17 0.17 0.04 0.62]
# Wakanda Forever [0.17 0.17 0.04 0.62]
# Wakanda Forever [0.17 0.18 0.04 0.61]
# Wakanda Forever [0.16 0.19 0.04 0.61]
# Wakanda Forever [0.18 0.16 0.05 0.61]
# Wakanda Forever [0.12 0.15 0.08 0.65]
# Wakanda Forever [0.09 0.09 0.12 0.7 ]
# Wakanda Forever [0.07 0.08 0.09 0.76]
# Wakanda Forever [0.08 0.15 0.14 0.63]
# Wakanda Forever [0.08 0.13 0.13 0.66]
# Wakanda Forever [0.08 0.16 0.13 0.63]
# Wakanda Forever [0.05 0.04 0.15 0.76]
# Wakanda Forever [0.07 0.02 0.04 0.87]
# Wakanda Forever [0.07 0.1  0.04 0.79]
# Wakanda Forever [0.14 0.15 0.04 0.67]
# Wakanda Forever [0.23 0.23 0.01 0.53]
# Wakanda Forever [0.24 0.2  0.01 0.55]
# Wakanda Forever [0.23 0.2  0.01 0.56]
# Wakanda Forever [0.2  0.19 0.01 0.6 ]
# Wakanda Forever [0.14 0.16 0.   0.7 ]
# Wakanda Forever [0.07 0.11 0.   0.82]
# Wakanda Forever [0.06 0.07 0.   0.87]
# Wakanda Forever [0.08 0.07 0.   0.85]
# Wakanda Forever [0.08 0.06 0.   0.86]
# Wakanda Forever [0.11 0.06 0.   0.83]
# Wakanda Forever [0.11 0.05 0.   0.84]
# Wakanda Forever [0.09 0.07 0.   0.84]
# Wakanda Forever [0.1  0.07 0.   0.83]
# Wakanda Forever [0.1  0.07 0.   0.83]
# Wakanda Forever [0.06 0.1  0.01 0.83]
# Wakanda Forever [0.04 0.16 0.1  0.7 ]
# Wakanda Forever [0.08 0.21 0.01 0.7 ]
# Wakanda Forever [0.03 0.07 0.01 0.89]
# Wakanda Forever [0.01 0.07 0.01 0.91]
# Wakanda Forever [0.03 0.07 0.01 0.89]
# Wakanda Forever [0.02 0.07 0.01 0.9 ]
# Wakanda Forever [0.   0.07 0.01 0.92]
# Wakanda Forever [0.02 0.07 0.01 0.9 ]
# Wakanda Forever [0.03 0.08 0.01 0.88]
# Wakanda Forever [0.02 0.06 0.01 0.91]
# Wakanda Forever [0.03 0.05 0.01 0.91]
# Wakanda Forever [0.03 0.04 0.1  0.83]
# Wakanda Forever [0.05 0.04 0.01 0.9 ]
# Wakanda Forever [0.07 0.05 0.01 0.87]
# Wakanda Forever [0.07 0.05 0.01 0.87]
# Wakanda Forever [0.06 0.05 0.01 0.88]
# Wakanda Forever [0.06 0.05 0.01 0.88]
# Wakanda Forever [0.06 0.05 0.01 0.88]
# Wakanda Forever [0.06 0.04 0.01 0.89]
# Wakanda Forever [0.1  0.17 0.09 0.64]
# Wakanda Forever [0.1  0.2  0.11 0.59]
# Wakanda Forever [0.17 0.24 0.   0.59]
# Wakanda Forever [0.2  0.19 0.   0.61]
# Wakanda Forever [0.15 0.18 0.   0.67]
# Wakanda Forever [0.14 0.16 0.   0.7 ]
# Wakanda Forever [0.14 0.18 0.   0.68]
# Wakanda Forever [0.14 0.19 0.   0.67]
# Wakanda Forever [0.13 0.18 0.   0.69]
# Wakanda Forever [0.13 0.18 0.   0.69]
# Wakanda Forever [0.12 0.17 0.   0.71]
# Wakanda Forever [0.12 0.17 0.   0.71]
# Wakanda Forever [0.12 0.16 0.   0.72]
# Wakanda Forever [0.12 0.15 0.   0.73]
# Wakanda Forever [0.1  0.15 0.   0.75]
# Wakanda Forever [0.12 0.16 0.   0.72]
# Wakanda Forever [0.13 0.16 0.   0.71]
# Wakanda Forever [0.11 0.15 0.   0.74]
# Wakanda Forever [0.1  0.13 0.   0.77]
# Wakanda Forever [0.1  0.14 0.   0.76]
# Wakanda Forever [0.12 0.15 0.   0.73]
# Wakanda Forever [0.12 0.16 0.   0.72]
# Wakanda Forever [0.12 0.16 0.   0.72]
# Wakanda Forever [0.12 0.14 0.   0.74]
# Wakanda Forever [0.12 0.14 0.   0.74]
# Wakanda Forever [0.12 0.14 0.   0.74]
# Wakanda Forever [0.09 0.1  0.   0.81]
# Wakanda Forever [0.12 0.05 0.   0.83]
# Wakanda Forever [0.12 0.07 0.   0.81]
# Wakanda Forever [0.12 0.07 0.   0.81]
# Wakanda Forever [0.09 0.06 0.   0.85]
# Wakanda Forever [0.09 0.05 0.   0.86]
# Wakanda Forever [0.1  0.04 0.   0.86]
# Wakanda Forever [0.09 0.05 0.   0.86]
# Wakanda Forever [0.1  0.05 0.   0.85]
# Wakanda Forever [0.12 0.07 0.   0.81]
# Wakanda Forever [0.13 0.24 0.   0.63]
# Wakanda Forever [0.12 0.36 0.   0.52]
# Wakanda Forever [0.11 0.35 0.   0.54]
# Wakanda Forever [0.11 0.37 0.   0.52]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.07 0.09 0.   0.84]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.07 0.06 0.   0.87]
# Wakanda Forever [0.07 0.06 0.   0.87]
# Wakanda Forever [0.1 0.1 0.  0.8]
# Sad [0.34 0.43 0.   0.23]
# Happy [0.45 0.45 0.01 0.09]
# Sad [0.36 0.55 0.01 0.08]
# Sad [0.41 0.47 0.02 0.1 ]
# Sad [0.33 0.51 0.   0.16]
# Sad [0.35 0.44 0.   0.21]
# Wakanda Forever [0.26 0.29 0.05 0.4 ]
# Wakanda Forever [0.2  0.22 0.05 0.53]
# Wakanda Forever [0.18 0.24 0.07 0.51]
# Wakanda Forever [0.15 0.2  0.13 0.52]
# Wakanda Forever [0.16 0.22 0.05 0.57]
# Wakanda Forever [0.17 0.21 0.05 0.57]
# Wakanda Forever [0.13 0.22 0.13 0.52]
# Wakanda Forever [0.14 0.23 0.13 0.5 ]
# Wakanda Forever [0.15 0.23 0.13 0.49]
# Wakanda Forever [0.16 0.22 0.12 0.5 ]
# Wakanda Forever [0.13 0.26 0.06 0.55]
# Wakanda Forever [0.09 0.24 0.13 0.54]
# Wakanda Forever [0.07 0.22 0.13 0.58]
# Wakanda Forever [0.1  0.19 0.13 0.58]
# Wakanda Forever [0.1  0.19 0.12 0.59]
# Wakanda Forever [0.04 0.16 0.12 0.68]
# Wakanda Forever [0.05 0.18 0.13 0.64]
# Wakanda Forever [0.07 0.18 0.13 0.62]
# Wakanda Forever [0.12 0.2  0.09 0.59]
# Wakanda Forever [0.13 0.23 0.05 0.59]
# Wakanda Forever [0.16 0.14 0.06 0.64]
# Wakanda Forever [0.17 0.15 0.03 0.65]
# Wakanda Forever [0.15 0.07 0.07 0.71]
# Wakanda Forever [0.14 0.07 0.03 0.76]
# Wakanda Forever [0.13 0.06 0.02 0.79]
# Wakanda Forever [0.07 0.01 0.02 0.9 ]
# Wakanda Forever [0.05 0.02 0.1  0.83]
# Wakanda Forever [0.07 0.09 0.01 0.83]
# Wakanda Forever [0.08 0.2  0.02 0.7 ]
# Sad [0.13 0.51 0.01 0.35]
# Sad [0.18 0.44 0.06 0.32]
# Sad [0.16 0.47 0.06 0.31]
# Sad [0.16 0.42 0.06 0.36]
# Sad [0.16 0.46 0.06 0.32]
# Sad [0.24 0.46 0.05 0.25]
# Sad [0.2  0.56 0.02 0.22]
# Sad [0.17 0.6  0.   0.23]
# Sad [0.16 0.59 0.   0.25]
# Sad [0.27 0.51 0.   0.22]
# Sad [0.27 0.48 0.   0.25]
# Sad [0.27 0.5  0.   0.23]
# Sad [0.24 0.5  0.   0.26]
# Sad [0.25 0.47 0.   0.28]
# Sad [0.24 0.49 0.   0.27]
# Sad [0.2  0.53 0.   0.27]
# Sad [0.2  0.55 0.   0.25]
# Sad [0.18 0.57 0.   0.25]
# Sad [0.19 0.55 0.   0.26]
# Sad [0.18 0.57 0.   0.25]
# Sad [0.2  0.62 0.   0.18]
# Sad [0.2  0.62 0.   0.18]
# Sad [0.2  0.63 0.   0.17]
# Sad [0.13 0.67 0.   0.2 ]
# Sad [0.13 0.67 0.   0.2 ]
# Sad [0.13 0.67 0.   0.2 ]
# Sad [0.14 0.68 0.   0.18]
# Sad [0.13 0.7  0.01 0.16]
# Sad [0.05 0.6  0.03 0.32]
# Sad [0.04 0.54 0.11 0.31]
# Sad [0.04 0.57 0.03 0.36]
# Sad [0.03 0.54 0.03 0.4 ]
# Sad [0.03 0.54 0.04 0.39]
# Sad [0.03 0.55 0.04 0.38]
# Sad [0.03 0.54 0.04 0.39]
# Sad [0.03 0.49 0.05 0.43]
# Sad [0.03 0.49 0.05 0.43]
# Sad [0.03 0.49 0.06 0.42]
# Sad [0.03 0.48 0.06 0.43]
# Sad [0.02 0.46 0.06 0.46]
# Wakanda Forever [0.02 0.44 0.06 0.48]
# Wakanda Forever [0.02 0.44 0.06 0.48]
# Wakanda Forever [0.02 0.44 0.06 0.48]
# Wakanda Forever [0.02 0.44 0.06 0.48]
# Wakanda Forever [0.02 0.44 0.06 0.48]
# Wakanda Forever [0.02 0.43 0.07 0.48]
# Wakanda Forever [0.02 0.43 0.07 0.48]
# Wakanda Forever [0.02 0.42 0.08 0.48]
# Wakanda Forever [0.02 0.42 0.08 0.48]
# Wakanda Forever [0.02 0.41 0.08 0.49]
# Wakanda Forever [0.02 0.45 0.07 0.46]
# Sad [0.02 0.43 0.12 0.43]
# Sad [0.03 0.44 0.12 0.41]
# Sad [0.03 0.47 0.12 0.38]
# Sad [0.03 0.44 0.25 0.28]
# Sad [0.04 0.45 0.26 0.25]
# Sad [0.03 0.48 0.27 0.22]
# Sad [0.03 0.48 0.26 0.23]
# Sad [0.02 0.45 0.31 0.22]
# Sad [0.02 0.42 0.38 0.18]
# Sad [0.02 0.4  0.4  0.18]
# Victorious [0.02 0.37 0.44 0.17]
# Victorious [0.02 0.37 0.44 0.17]
# Victorious [0.02 0.37 0.44 0.17]
# Victorious [0.02 0.36 0.44 0.18]
# Victorious [0.02 0.36 0.44 0.18]
# Victorious [0.02 0.37 0.44 0.17]
# Victorious [0.01 0.37 0.45 0.17]
# Victorious [0.01 0.36 0.45 0.18]
# Victorious [0.01 0.35 0.49 0.15]
# Victorious [0.   0.36 0.49 0.15]
# Victorious [0.   0.34 0.49 0.17]
# Victorious [0.   0.34 0.5  0.16]
# Victorious [0.01 0.31 0.52 0.16]
# Sad [0.02 0.41 0.29 0.28]
# Sad [0.   0.43 0.27 0.3 ]
# Sad [0.   0.41 0.27 0.32]
# Sad [0.   0.43 0.25 0.32]
# Sad [0.   0.46 0.22 0.32]
# Sad [0.   0.49 0.19 0.32]
# Sad [0.   0.47 0.19 0.34]
# Sad [0.   0.48 0.19 0.33]
# Sad [0.02 0.49 0.19 0.3 ]
# Sad [0.02 0.49 0.18 0.31]
# Sad [0.02 0.43 0.15 0.4 ]
# Sad [0.02 0.43 0.15 0.4 ]
# Sad [0.02 0.45 0.12 0.41]
# Sad [0.02 0.45 0.12 0.41]
# Wakanda Forever [0.02 0.44 0.09 0.45]
# Wakanda Forever [0.02 0.44 0.09 0.45]
# Wakanda Forever [0.02 0.44 0.09 0.45]
# Wakanda Forever [0.02 0.44 0.09 0.45]
# Wakanda Forever [0.02 0.44 0.08 0.46]
# Sad [0.02 0.45 0.08 0.45]
# Sad [0.02 0.46 0.08 0.44]
# Wakanda Forever [0.02 0.43 0.08 0.47]
# Wakanda Forever [0.02 0.43 0.07 0.48]
# Wakanda Forever [0.03 0.41 0.08 0.48]
# Wakanda Forever [0.03 0.43 0.07 0.47]
# Wakanda Forever [0.03 0.43 0.07 0.47]
# Wakanda Forever [0.03 0.41 0.07 0.49]
# Wakanda Forever [0.03 0.41 0.07 0.49]
# Wakanda Forever [0.03 0.42 0.07 0.48]
# Wakanda Forever [0.03 0.42 0.07 0.48]
# Wakanda Forever [0.03 0.42 0.07 0.48]
# Wakanda Forever [0.03 0.42 0.07 0.48]
# Wakanda Forever [0.03 0.41 0.08 0.48]
# Wakanda Forever [0.03 0.41 0.08 0.48]
# Wakanda Forever [0.03 0.41 0.08 0.48]
# Sad [0.02 0.46 0.07 0.45]
# Sad [0.01 0.54 0.06 0.39]
# Sad [0.04 0.62 0.05 0.29]
# Sad [0.05 0.62 0.05 0.28]
# Sad [0.03 0.67 0.05 0.25]
# Sad [0.02 0.68 0.05 0.25]
# Sad [0.05 0.66 0.02 0.27]
# Sad [0.05 0.68 0.01 0.26]
# Sad [0.05 0.69 0.01 0.25]
# Sad [0.05 0.68 0.01 0.26]
# Sad [0.05 0.69 0.01 0.25]
# Sad [0.05 0.69 0.01 0.25]
# Sad [0.05 0.71 0.02 0.22]
# Sad [0.05 0.7  0.02 0.23]
# Sad [0.06 0.69 0.02 0.23]
# Sad [0.05 0.69 0.02 0.24]
# Sad [0.04 0.71 0.02 0.23]
# Sad [0.04 0.7  0.02 0.24]
# Sad [0.04 0.7  0.02 0.24]
# Sad [0.04 0.7  0.02 0.24]
# Sad [0.04 0.7  0.02 0.24]
# Sad [0.04 0.7  0.02 0.24]
# Sad [0.04 0.7  0.02 0.24]
# Sad [0.04 0.73 0.02 0.21]
# Sad [0.03 0.83 0.02 0.12]
# Sad [0.04 0.77 0.02 0.17]
# Sad [0.11 0.74 0.   0.15]
# Wakanda Forever [0.01 0.12 0.03 0.84]
# Wakanda Forever [0.09 0.15 0.07 0.69]
# Wakanda Forever [0.12 0.17 0.03 0.68]
# Wakanda Forever [0.17 0.21 0.05 0.57]
# Wakanda Forever [0.25 0.16 0.02 0.57]
# Wakanda Forever [0.19 0.15 0.15 0.51]
# Wakanda Forever [0.19 0.2  0.13 0.48]
# Wakanda Forever [0.21 0.23 0.05 0.51]
# Wakanda Forever [0.18 0.23 0.05 0.54]
# Wakanda Forever [0.17 0.24 0.05 0.54]
# Wakanda Forever [0.14 0.25 0.05 0.56]
# Wakanda Forever [0.16 0.23 0.04 0.57]
# Wakanda Forever [0.26 0.22 0.04 0.48]
# Wakanda Forever [0.26 0.26 0.03 0.45]
# Wakanda Forever [0.24 0.28 0.   0.48]
# Sad [0.26 0.37 0.   0.37]
# Wakanda Forever [0.33 0.29 0.01 0.37]
# Happy [0.35 0.29 0.01 0.35]
# Happy [0.39 0.28 0.01 0.32]
# Happy [0.43 0.26 0.02 0.29]
# Happy [0.42 0.25 0.02 0.31]
# Happy [0.37 0.31 0.02 0.3 ]
# Happy [0.4  0.31 0.02 0.27]
# Happy [0.38 0.31 0.01 0.3 ]
# Happy [0.39 0.3  0.02 0.29]
# Happy [0.36 0.34 0.01 0.29]
# Happy [0.37 0.33 0.01 0.29]
# Happy [0.35 0.34 0.01 0.3 ]
# Happy [0.35 0.34 0.01 0.3 ]
# Happy [0.36 0.35 0.01 0.28]
# Happy [0.39 0.39 0.01 0.21]
# Happy [0.39 0.39 0.01 0.21]
# Happy [0.39 0.39 0.01 0.21]
# Sad [0.37 0.42 0.01 0.2 ]
# Sad [0.37 0.44 0.01 0.18]
# Sad [0.37 0.44 0.01 0.18]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.35 0.44 0.01 0.2 ]
# Sad [0.3  0.49 0.01 0.2 ]
# Sad [0.32 0.49 0.01 0.18]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.34 0.49 0.01 0.16]
# Sad [0.35 0.47 0.01 0.17]
# Sad [0.35 0.47 0.01 0.17]
# Sad [0.35 0.47 0.01 0.17]
# Sad [0.33 0.48 0.01 0.18]
# Sad [0.34 0.48 0.01 0.17]
# Happy [0.42 0.39 0.01 0.18]
# Happy [0.43 0.38 0.01 0.18]
# Happy [0.47 0.35 0.01 0.17]
# Happy [0.45 0.37 0.01 0.17]
# Happy [0.44 0.38 0.01 0.17]
# Happy [0.44 0.38 0.01 0.17]
# Happy [0.44 0.38 0.01 0.17]
# Happy [0.45 0.37 0.01 0.17]
# Sad [0.37 0.45 0.01 0.17]
# Sad [0.37 0.45 0.01 0.17]
# Sad [0.37 0.46 0.01 0.16]
# Sad [0.37 0.46 0.01 0.16]
# Sad [0.35 0.45 0.01 0.19]
# Sad [0.39 0.41 0.01 0.19]
# Sad [0.39 0.43 0.01 0.17]
# Sad [0.39 0.43 0.01 0.17]
# Sad [0.38 0.43 0.01 0.18]
# Sad [0.38 0.43 0.01 0.18]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.38 0.43 0.01 0.18]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.37 0.44 0.01 0.18]
# Sad [0.37 0.43 0.01 0.19]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.39 0.41 0.01 0.19]
# Sad [0.39 0.41 0.01 0.19]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.36 0.43 0.01 0.2 ]
# Sad [0.32 0.49 0.01 0.18]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.36 0.47 0.01 0.16]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.35 0.48 0.01 0.16]
# Sad [0.35 0.47 0.01 0.17]
# Sad [0.35 0.47 0.01 0.17]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.32 0.49 0.01 0.18]
# Sad [0.34 0.48 0.01 0.17]
# Sad [0.32 0.5  0.01 0.17]
# Sad [0.38 0.41 0.01 0.2 ]
# Sad [0.38 0.42 0.03 0.17]
# Sad [0.38 0.41 0.03 0.18]
# Sad [0.38 0.41 0.03 0.18]
# Sad [0.38 0.41 0.03 0.18]
# Happy [0.4  0.39 0.02 0.19]
# Happy [0.42 0.36 0.02 0.2 ]
# Happy [0.42 0.38 0.02 0.18]
# Happy [0.48 0.34 0.02 0.16]
# Happy [0.49 0.34 0.02 0.15]
# Happy [0.45 0.35 0.02 0.18]
# Happy [0.46 0.35 0.02 0.17]
# Happy [0.45 0.34 0.02 0.19]
# Happy [0.46 0.34 0.02 0.18]
# Happy [0.46 0.35 0.02 0.17]
# Happy [0.45 0.36 0.02 0.17]
# Happy [0.43 0.36 0.02 0.19]
# Happy [0.44 0.36 0.02 0.18]
# Happy [0.44 0.37 0.02 0.17]
# Happy [0.44 0.37 0.02 0.17]
# Happy [0.42 0.39 0.02 0.17]
# Happy [0.42 0.41 0.02 0.15]
# Happy [0.43 0.41 0.01 0.15]
# Happy [0.42 0.42 0.01 0.15]
# Happy [0.41 0.41 0.01 0.17]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.38 0.44 0.01 0.17]
# Sad [0.38 0.43 0.01 0.18]
# Sad [0.38 0.41 0.02 0.19]
# Happy [0.42 0.41 0.01 0.16]
# Sad [0.39 0.43 0.01 0.17]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.37 0.44 0.01 0.18]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.38 0.43 0.01 0.18]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.4  0.43 0.01 0.16]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.4  0.41 0.01 0.18]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.38 0.44 0.01 0.17]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.38 0.42 0.01 0.19]
# Sad [0.35 0.41 0.02 0.22]
# Sad [0.28 0.38 0.02 0.32]
# Sad [0.31 0.42 0.02 0.25]
# Sad [0.29 0.39 0.05 0.27]
# Sad [0.25 0.36 0.05 0.34]
# Sad [0.29 0.34 0.07 0.3 ]
# Sad [0.32 0.41 0.05 0.22]
# Happy [0.36 0.36 0.02 0.26]
# Happy [0.39 0.39 0.03 0.19]
# Sad [0.36 0.37 0.02 0.25]
# Sad [0.27 0.44 0.02 0.27]
# Sad [0.28 0.42 0.02 0.28]
# Sad [0.32 0.45 0.02 0.21]
# Sad [0.34 0.42 0.04 0.2 ]
# Sad [0.27 0.47 0.02 0.24]
# Sad [0.32 0.43 0.02 0.23]
# Sad [0.34 0.38 0.02 0.26]
# Sad [0.3  0.4  0.02 0.28]
# Sad [0.33 0.39 0.02 0.26]
# Sad [0.34 0.39 0.02 0.25]
# Sad [0.3  0.4  0.02 0.28]
# Sad [0.34 0.41 0.02 0.23]
# Sad [0.33 0.38 0.02 0.27]
# Sad [0.31 0.4  0.02 0.27]
# Sad [0.34 0.42 0.05 0.19]
# Sad [0.35 0.37 0.05 0.23]
# Sad [0.35 0.39 0.05 0.21]
# Sad [0.36 0.37 0.05 0.22]
# Sad [0.35 0.36 0.04 0.25]
# Sad [0.31 0.4  0.05 0.24]
# Sad [0.33 0.37 0.02 0.28]
# Sad [0.29 0.37 0.02 0.32]
# Sad [0.3  0.39 0.03 0.28]
# Sad [0.32 0.41 0.02 0.25]
# Sad [0.33 0.45 0.02 0.2 ]
# Sad [0.33 0.44 0.02 0.21]
# Sad [0.34 0.41 0.03 0.22]
# Sad [0.27 0.43 0.02 0.28]
# Sad [0.28 0.44 0.02 0.26]
# Sad [0.27 0.44 0.02 0.27]
# Sad [0.28 0.47 0.02 0.23]
# Sad [0.33 0.43 0.02 0.22]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.37 0.44 0.01 0.18]
# Sad [0.38 0.43 0.01 0.18]
# Sad [0.4  0.42 0.01 0.17]
# Happy [0.41 0.39 0.01 0.19]
# Sad [0.34 0.46 0.01 0.19]
# Sad [0.32 0.48 0.02 0.18]
# Sad [0.34 0.45 0.02 0.19]
# Sad [0.34 0.44 0.03 0.19]
# Sad [0.35 0.45 0.04 0.16]
# Wakanda Forever [0.23 0.28 0.13 0.36]
# Wakanda Forever [0.21 0.32 0.06 0.41]
# Wakanda Forever [0.22 0.33 0.02 0.43]
# Wakanda Forever [0.19 0.38 0.02 0.41]
# Wakanda Forever [0.22 0.35 0.02 0.41]
# Wakanda Forever [0.2  0.37 0.02 0.41]
# Wakanda Forever [0.22 0.34 0.02 0.42]
# Sad [0.17 0.41 0.02 0.4 ]
# Wakanda Forever [0.2  0.36 0.02 0.42]
# Wakanda Forever [0.18 0.39 0.02 0.41]
# Sad [0.16 0.41 0.02 0.41]
# Sad [0.17 0.36 0.14 0.33]
# Sad [0.19 0.32 0.19 0.3 ]
# Sad [0.17 0.34 0.19 0.3 ]
# Sad [0.17 0.35 0.17 0.31]
# Sad [0.14 0.4  0.17 0.29]
# Sad [0.16 0.38 0.17 0.29]
# Sad [0.16 0.37 0.18 0.29]
# Sad [0.17 0.38 0.17 0.28]
# Sad [0.15 0.39 0.18 0.28]
# Sad [0.15 0.39 0.18 0.28]
# Sad [0.19 0.35 0.18 0.28]
# Sad [0.17 0.35 0.21 0.27]
# Sad [0.13 0.38 0.22 0.27]
# Sad [0.13 0.35 0.26 0.26]
# Sad [0.15 0.33 0.27 0.25]
# Sad [0.12 0.41 0.29 0.18]
# Sad [0.12 0.41 0.29 0.18]
# Sad [0.12 0.4  0.28 0.2 ]
# Sad [0.11 0.42 0.32 0.15]
# Sad [0.13 0.39 0.31 0.17]
# Sad [0.15 0.35 0.32 0.18]
# Sad [0.13 0.36 0.32 0.19]
# Victorious [0.16 0.3  0.37 0.17]
# Victorious [0.13 0.33 0.4  0.14]
# Victorious [0.13 0.29 0.43 0.15]
# Victorious [0.09 0.31 0.48 0.12]
# Victorious [0.09 0.32 0.51 0.08]
# Victorious [0.1  0.3  0.53 0.07]
# Victorious [0.12 0.3  0.52 0.06]
# Victorious [0.12 0.28 0.56 0.04]
# Victorious [0.09 0.26 0.6  0.05]
# Wakanda Forever [0.17 0.24 0.29 0.3 ]
# Wakanda Forever [0.1  0.25 0.17 0.48]
# Wakanda Forever [0.13 0.23 0.13 0.51]
# Wakanda Forever [0.22 0.28 0.09 0.41]
# Wakanda Forever [0.2  0.29 0.07 0.44]
# Wakanda Forever [0.17 0.34 0.06 0.43]
# Wakanda Forever [0.19 0.33 0.06 0.42]
# Wakanda Forever [0.17 0.35 0.06 0.42]
# Wakanda Forever [0.21 0.32 0.06 0.41]
# Wakanda Forever [0.17 0.36 0.06 0.41]
# Wakanda Forever [0.19 0.37 0.06 0.38]
# Sad [0.22 0.42 0.05 0.31]
# Wakanda Forever [0.17 0.28 0.24 0.31]
# Sad [0.15 0.31 0.24 0.3 ]
# Sad [0.18 0.32 0.25 0.25]
# Sad [0.19 0.31 0.23 0.27]
# Wakanda Forever [0.23 0.28 0.15 0.34]
# Wakanda Forever [0.2  0.26 0.26 0.28]
# Sad [0.19 0.3  0.29 0.22]
# Victorious [0.18 0.28 0.31 0.23]
# Victorious [0.19 0.28 0.31 0.22]
# Victorious [0.18 0.28 0.33 0.21]
# Victorious [0.18 0.27 0.33 0.22]
# Victorious [0.19 0.28 0.33 0.2 ]
# Victorious [0.2  0.3  0.34 0.16]
# Sad [0.18 0.36 0.3  0.16]
# Victorious [0.19 0.31 0.34 0.16]
# Sad [0.18 0.34 0.26 0.22]
# Sad [0.33 0.44 0.11 0.12]
# Sad [0.36 0.43 0.08 0.13]
# Happy [0.44 0.4  0.05 0.11]
# Sad [0.38 0.45 0.05 0.12]
# Sad [0.39 0.48 0.01 0.12]
# Sad [0.39 0.47 0.01 0.13]
# Sad [0.38 0.48 0.01 0.13]
# Sad [0.38 0.48 0.02 0.12]
# Sad [0.38 0.47 0.02 0.13]
# Sad [0.38 0.47 0.02 0.13]
# Sad [0.39 0.46 0.02 0.13]
# Sad [0.39 0.48 0.02 0.11]
# Sad [0.4  0.45 0.02 0.13]
# Happy [0.46 0.42 0.01 0.11]
# Happy [0.45 0.41 0.02 0.12]
# Sad [0.43 0.46 0.01 0.1 ]
# Sad [0.34 0.51 0.01 0.14]
# Sad [0.33 0.51 0.01 0.15]
# Sad [0.3  0.54 0.01 0.15]
# Sad [0.29 0.55 0.01 0.15]
# Sad [0.31 0.53 0.01 0.15]
# Sad [0.3  0.54 0.01 0.15]
# Sad [0.33 0.52 0.01 0.14]
# Sad [0.34 0.52 0.01 0.13]
# Sad [0.35 0.51 0.01 0.13]
# Sad [0.29 0.56 0.01 0.14]
# Sad [0.31 0.56 0.01 0.12]
# Sad [0.31 0.56 0.01 0.12]
# Sad [0.33 0.55 0.01 0.11]
# Happy [0.45 0.45 0.02 0.08]
# Happy [0.45 0.41 0.03 0.11]
# Happy [0.47 0.42 0.03 0.08]
# Sad [0.43 0.44 0.04 0.09]
# Sad [0.45 0.46 0.03 0.06]
# Sad [0.46 0.47 0.02 0.05]
# Happy [0.48 0.44 0.03 0.05]
# Happy [0.48 0.42 0.04 0.06]
# Happy [0.49 0.43 0.03 0.05]
# Happy [0.49 0.43 0.03 0.05]
# Happy [0.5  0.43 0.02 0.05]
# Happy [0.5  0.44 0.02 0.04]
# Happy [0.49 0.43 0.03 0.05]
# Happy [0.49 0.43 0.03 0.05]
# Happy [0.49 0.43 0.03 0.05]
# Happy [0.5  0.43 0.02 0.05]
# Happy [0.53 0.4  0.02 0.05]
# Happy [0.53 0.4  0.02 0.05]
# Happy [0.54 0.4  0.02 0.04]
# Sad [0.4  0.5  0.01 0.09]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.43 0.47 0.01 0.09]
# Happy [0.46 0.43 0.01 0.1 ]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.41 0.51 0.01 0.07]
# Sad [0.42 0.49 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.39 0.54 0.01 0.06]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.38 0.53 0.01 0.08]
# Sad [0.38 0.53 0.01 0.08]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.42 0.49 0.01 0.08]
# Sad [0.41 0.5  0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.4  0.51 0.01 0.08]
# Sad [0.39 0.52 0.01 0.08]
# Sad [0.36 0.55 0.01 0.08]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.32 0.59 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.29 0.62 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.29 0.62 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.29 0.62 0.01 0.08]
# Sad [0.33 0.6  0.01 0.06]
# Sad [0.32 0.6  0.01 0.07]
# Sad [0.31 0.6  0.01 0.08]
# Sad [0.31 0.6  0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.31 0.6  0.01 0.08]
# Sad [0.18 0.58 0.08 0.16]
# Sad [0.26 0.5  0.08 0.16]
# Sad [0.26 0.38 0.08 0.28]
# Sad [0.21 0.36 0.12 0.31]
# Sad [0.24 0.38 0.08 0.3 ]
# Sad [0.21 0.37 0.11 0.31]
# Sad [0.22 0.39 0.1  0.29]
# Sad [0.22 0.4  0.11 0.27]
# Sad [0.21 0.42 0.09 0.28]
# Sad [0.23 0.44 0.08 0.25]
# Sad [0.24 0.48 0.07 0.21]
# Sad [0.24 0.51 0.06 0.19]
# Sad [0.25 0.57 0.03 0.15]
# Sad [0.26 0.54 0.04 0.16]
# Sad [0.23 0.56 0.04 0.17]
# Sad [0.23 0.58 0.02 0.17]
# Sad [0.25 0.58 0.02 0.15]
# Sad [0.43 0.47 0.01 0.09]
# Sad [0.36 0.52 0.01 0.11]
# Sad [0.37 0.49 0.01 0.13]
# Sad [0.37 0.51 0.01 0.11]
# Sad [0.34 0.5  0.01 0.15]
# Sad [0.4  0.47 0.01 0.12]
# Sad [0.42 0.43 0.01 0.14]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.38 0.45 0.   0.17]
# Sad [0.39 0.43 0.   0.18]
# Sad [0.37 0.4  0.   0.23]
# Sad [0.31 0.35 0.   0.34]
# Happy [0.35 0.35 0.   0.3 ]
# Wakanda Forever [0.19 0.26 0.   0.55]
# Sad [0.37 0.39 0.   0.24]
# Wakanda Forever [0.23 0.33 0.   0.44]
# Wakanda Forever [0.22 0.32 0.   0.46]
# Wakanda Forever [0.27 0.33 0.   0.4 ]
# Sad [0.27 0.37 0.   0.36]
# Sad [0.28 0.38 0.   0.34]
# Sad [0.25 0.39 0.   0.36]
# Sad [0.33 0.38 0.   0.29]
# Happy [0.4  0.38 0.   0.22]
# Happy [0.4  0.38 0.   0.22]
# Happy [0.42 0.39 0.   0.19]
# Sad [0.4  0.42 0.   0.18]
# Sad [0.37 0.46 0.   0.17]
# Sad [0.37 0.46 0.   0.17]
# Sad [0.37 0.48 0.   0.15]
# Sad [0.36 0.47 0.   0.17]
# Sad [0.36 0.47 0.   0.17]
# Sad [0.36 0.47 0.   0.17]
# Sad [0.36 0.44 0.   0.2 ]
# Sad [0.35 0.45 0.   0.2 ]
# Sad [0.36 0.43 0.   0.21]
# Sad [0.36 0.43 0.   0.21]
# Sad [0.34 0.43 0.   0.23]
# Sad [0.35 0.43 0.   0.22]
# Sad [0.32 0.41 0.   0.27]
# Sad [0.36 0.41 0.   0.23]
# Sad [0.32 0.4  0.   0.28]
# Sad [0.35 0.42 0.   0.23]
# Sad [0.3  0.41 0.   0.29]
# Sad [0.35 0.43 0.   0.22]
# Sad [0.34 0.42 0.   0.24]
# Sad [0.36 0.43 0.   0.21]
# Sad [0.36 0.47 0.   0.17]
# Sad [0.37 0.51 0.01 0.11]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.3  0.57 0.02 0.11]
# Sad [0.24 0.64 0.02 0.1 ]
# Sad [0.19 0.67 0.02 0.12]
# Sad [0.2  0.66 0.01 0.13]
# Sad [0.22 0.7  0.01 0.07]
# Sad [0.22 0.7  0.   0.08]
# Sad [0.31 0.62 0.01 0.06]
# Sad [0.36 0.52 0.   0.12]
# Sad [0.32 0.44 0.   0.24]
# Wakanda Forever [0.22 0.38 0.   0.4 ]
# Sad [0.25 0.39 0.   0.36]
# Sad [0.31 0.42 0.   0.27]
# Wakanda Forever [0.18 0.23 0.   0.59]
# Wakanda Forever [0.12 0.13 0.   0.75]
# Wakanda Forever [0.1  0.13 0.   0.77]
# Wakanda Forever [0.11 0.13 0.   0.76]
# Wakanda Forever [0.09 0.13 0.   0.78]
# Wakanda Forever [0.1  0.13 0.   0.77]
# Wakanda Forever [0.1  0.13 0.   0.77]
# Wakanda Forever [0.1  0.13 0.   0.77]
# Wakanda Forever [0.09 0.12 0.   0.79]
# Wakanda Forever [0.09 0.11 0.   0.8 ]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.08 0.1  0.   0.82]
# Wakanda Forever [0.06 0.1  0.   0.84]
# Wakanda Forever [0.08 0.08 0.   0.84]
# Wakanda Forever [0.06 0.09 0.   0.85]
# Wakanda Forever [0.06 0.12 0.   0.82]
# Wakanda Forever [0.14 0.25 0.   0.61]
# Sad [0.3  0.51 0.02 0.17]
# Sad [0.31 0.49 0.02 0.18]
# Sad [0.34 0.52 0.01 0.13]
# Sad [0.29 0.56 0.01 0.14]
# Sad [0.34 0.51 0.01 0.14]
# Sad [0.35 0.48 0.01 0.16]
# Sad [0.35 0.5  0.   0.15]
# Sad [0.36 0.43 0.   0.21]
# Sad [0.36 0.44 0.   0.2 ]
# Sad [0.4  0.44 0.01 0.15]
# Sad [0.38 0.46 0.   0.16]
# Sad [0.35 0.5  0.01 0.14]
# Sad [0.35 0.49 0.01 0.15]
# Sad [0.34 0.46 0.   0.2 ]
# Sad [0.24 0.31 0.14 0.31]
# Sad [0.33 0.43 0.   0.24]
# Sad [0.33 0.47 0.   0.2 ]
# Sad [0.34 0.49 0.   0.17]
# Sad [0.31 0.56 0.01 0.12]
# Sad [0.28 0.6  0.   0.12]
# Sad [0.25 0.63 0.   0.12]
# Sad [0.32 0.56 0.01 0.11]
# Sad [0.32 0.58 0.   0.1 ]
# Sad [0.3  0.44 0.   0.26]
# Sad [0.29 0.46 0.   0.25]
# Sad [0.3  0.44 0.   0.26]
# Sad [0.3  0.44 0.   0.26]
# Sad [0.26 0.44 0.   0.3 ]
# Sad [0.29 0.46 0.   0.25]
# Sad [0.27 0.45 0.   0.28]
# Sad [0.24 0.4  0.   0.36]
# Sad [0.23 0.4  0.   0.37]
# Wakanda Forever [0.22 0.36 0.   0.42]
# Wakanda Forever [0.23 0.34 0.   0.43]
# Wakanda Forever [0.16 0.28 0.   0.56]
# Wakanda Forever [0.07 0.18 0.   0.75]
# Wakanda Forever [0.07 0.14 0.   0.79]
# Wakanda Forever [0.08 0.12 0.   0.8 ]
# Wakanda Forever [0.07 0.12 0.   0.81]
# Wakanda Forever [0.09 0.12 0.   0.79]
# Wakanda Forever [0.07 0.11 0.   0.82]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.09 0.1  0.   0.81]
# Wakanda Forever [0.08 0.1  0.   0.82]
# Wakanda Forever [0.07 0.09 0.   0.84]
# Wakanda Forever [0.08 0.08 0.   0.84]
# Wakanda Forever [0.08 0.08 0.   0.84]
# Wakanda Forever [0.07 0.08 0.   0.85]
# Wakanda Forever [0.06 0.1  0.   0.84]
# Wakanda Forever [0.06 0.11 0.   0.83]
# Wakanda Forever [0.07 0.11 0.   0.82]
# Wakanda Forever [0.07 0.09 0.   0.84]
# Wakanda Forever [0.07 0.09 0.   0.84]
# Wakanda Forever [0.07 0.11 0.   0.82]
# Wakanda Forever [0.07 0.13 0.   0.8 ]
# Wakanda Forever [0.18 0.32 0.   0.5 ]
# Sad [0.33 0.49 0.   0.18]
# Sad [0.33 0.5  0.01 0.16]
# Sad [0.31 0.5  0.01 0.18]
# Sad [0.26 0.5  0.02 0.22]
# Sad [0.28 0.48 0.02 0.22]
# Sad [0.32 0.49 0.01 0.18]
# Sad [0.31 0.51 0.01 0.17]
# Sad [0.32 0.49 0.01 0.18]
# Sad [0.34 0.46 0.02 0.18]
# Sad [0.33 0.48 0.01 0.18]
# Sad [0.33 0.48 0.01 0.18]
# Sad [0.33 0.46 0.01 0.2 ]
# Sad [0.34 0.45 0.01 0.2 ]
# Sad [0.34 0.45 0.01 0.2 ]
# Sad [0.32 0.46 0.01 0.21]
# Sad [0.32 0.47 0.   0.21]
# Sad [0.32 0.47 0.   0.21]
# Sad [0.3  0.47 0.   0.23]
# Sad [0.31 0.48 0.01 0.2 ]
# Sad [0.29 0.47 0.01 0.23]
# Sad [0.29 0.46 0.01 0.24]
# Sad [0.27 0.43 0.   0.3 ]
# Sad [0.25 0.4  0.   0.35]
# Sad [0.29 0.46 0.   0.25]
# Sad [0.26 0.45 0.   0.29]
# Sad [0.23 0.41 0.   0.36]
# Sad [0.22 0.4  0.   0.38]
# Sad [0.23 0.42 0.   0.35]
# Wakanda Forever [0.22 0.36 0.   0.42]
# Wakanda Forever [0.23 0.31 0.   0.46]
# Wakanda Forever [0.13 0.25 0.   0.62]
# Wakanda Forever [0.23 0.3  0.   0.47]
# Wakanda Forever [0.24 0.34 0.   0.42]
# Sad [0.23 0.4  0.   0.37]
# Wakanda Forever [0.22 0.37 0.   0.41]
# Sad [0.22 0.42 0.   0.36]
# Sad [0.23 0.39 0.   0.38]
# Wakanda Forever [0.22 0.34 0.   0.44]
# Wakanda Forever [0.22 0.34 0.   0.44]
# Wakanda Forever [0.21 0.3  0.   0.49]
# Wakanda Forever [0.21 0.32 0.   0.47]
# Sad [0.22 0.41 0.   0.37]
# Sad [0.23 0.46 0.   0.31]
# Sad [0.22 0.46 0.   0.32]
# Sad [0.23 0.46 0.   0.31]
# Sad [0.23 0.44 0.   0.33]
# Sad [0.23 0.46 0.   0.31]
# Sad [0.24 0.47 0.   0.29]
# Sad [0.24 0.47 0.   0.29]
# Sad [0.24 0.43 0.   0.33]
# Sad [0.21 0.4  0.   0.39]
# Sad [0.25 0.43 0.   0.32]
# Sad [0.25 0.43 0.   0.32]
# Sad [0.24 0.43 0.   0.33]
# Sad [0.24 0.43 0.   0.33]
# Sad [0.23 0.45 0.   0.32]
# Sad [0.24 0.45 0.   0.31]
# Sad [0.25 0.44 0.   0.31]
# Sad [0.26 0.41 0.   0.33]
# Sad [0.26 0.42 0.   0.32]
# Sad [0.29 0.36 0.   0.35]
# Sad [0.3  0.35 0.   0.35]
# Sad [0.3  0.39 0.   0.31]
# Sad [0.31 0.38 0.   0.31]
# Sad [0.32 0.42 0.   0.26]
# Sad [0.3  0.38 0.   0.32]
# Sad [0.33 0.4  0.   0.27]
# Sad [0.24 0.43 0.   0.33]
# Sad [0.29 0.44 0.   0.27]
# Sad [0.23 0.46 0.   0.31]
# Sad [0.23 0.47 0.   0.3 ]
# Sad [0.23 0.42 0.   0.35]
# Sad [0.22 0.47 0.   0.31]
# Sad [0.25 0.47 0.   0.28]
# Sad [0.23 0.46 0.   0.31]
# Sad [0.19 0.46 0.   0.35]
# Sad [0.19 0.47 0.   0.34]
# Sad [0.19 0.46 0.   0.35]
# Sad [0.21 0.45 0.   0.34]
# Sad [0.26 0.46 0.   0.28]
# Sad [0.29 0.46 0.   0.25]
# Sad [0.29 0.46 0.   0.25]
# Sad [0.29 0.43 0.   0.28]
# Sad [0.24 0.42 0.   0.34]
# Sad [0.22 0.4  0.   0.38]
# Sad [0.23 0.41 0.   0.36]
# Sad [0.22 0.42 0.   0.36]
# Sad [0.21 0.41 0.   0.38]
# Sad [0.23 0.44 0.   0.33]
# Sad [0.26 0.45 0.   0.29]
# Sad [0.28 0.46 0.   0.26]
# Sad [0.29 0.49 0.   0.22]
# Sad [0.28 0.47 0.   0.25]
# Sad [0.29 0.47 0.   0.24]
# Sad [0.25 0.45 0.   0.3 ]
# Sad [0.26 0.4  0.   0.34]
# Sad [0.25 0.4  0.   0.35]
# Sad [0.22 0.39 0.   0.39]
# Wakanda Forever [0.22 0.31 0.   0.47]
# Wakanda Forever [0.09 0.23 0.   0.68]
# Wakanda Forever [0.11 0.2  0.   0.69]
# Wakanda Forever [0.09 0.19 0.   0.72]
# Wakanda Forever [0.09 0.14 0.   0.77]
# Wakanda Forever [0.09 0.14 0.   0.77]
# Wakanda Forever [0.08 0.16 0.   0.76]
# Wakanda Forever [0.09 0.13 0.   0.78]
# Wakanda Forever [0.09 0.11 0.   0.8 ]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.09 0.11 0.   0.8 ]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.09 0.11 0.   0.8 ]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.09 0.11 0.   0.8 ]
# Wakanda Forever [0.08 0.11 0.   0.81]
# Wakanda Forever [0.09 0.12 0.   0.79]
# Wakanda Forever [0.07 0.16 0.   0.77]
# Wakanda Forever [0.07 0.21 0.   0.72]
# Wakanda Forever [0.07 0.19 0.   0.74]
# Wakanda Forever [0.06 0.16 0.   0.78]
# Wakanda Forever [0.06 0.17 0.   0.77]
# Wakanda Forever [0.22 0.38 0.   0.4 ]
# Wakanda Forever [0.16 0.29 0.   0.55]
# Wakanda Forever [0.23 0.32 0.   0.45]
# Sad [0.23 0.42 0.   0.35]
# Sad [0.27 0.43 0.   0.3 ]
# Sad [0.3  0.47 0.   0.23]
# Sad [0.34 0.43 0.01 0.22]
# Sad [0.33 0.43 0.01 0.23]
# Sad [0.36 0.42 0.01 0.21]
# Sad [0.35 0.41 0.01 0.23]
# Sad [0.36 0.4  0.   0.24]
# Sad [0.32 0.41 0.   0.27]
# Sad [0.29 0.4  0.   0.31]
# Wakanda Forever [0.24 0.35 0.   0.41]
# Wakanda Forever [0.23 0.22 0.   0.55]
# Wakanda Forever [0.15 0.16 0.   0.69]
# Wakanda Forever [0.06 0.09 0.   0.85]
# Wakanda Forever [0.06 0.07 0.   0.87]
# Wakanda Forever [0.06 0.06 0.   0.88]
# Wakanda Forever [0.06 0.06 0.   0.88]
# Wakanda Forever [0.06 0.06 0.   0.88]
# Wakanda Forever [0.05 0.07 0.   0.88]
# Wakanda Forever [0.05 0.07 0.   0.88]
# Wakanda Forever [0.05 0.06 0.   0.89]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.05 0.   0.91]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.08 0.   0.88]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.05 0.   0.91]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.05 0.   0.91]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.04 0.06 0.   0.9 ]
# Wakanda Forever [0.05 0.06 0.   0.89]
# Wakanda Forever [0.06 0.07 0.   0.87]
# Wakanda Forever [0.06 0.1  0.   0.84]
# Wakanda Forever [0.21 0.19 0.   0.6 ]
# Wakanda Forever [0.24 0.25 0.   0.51]
# Wakanda Forever [0.25 0.3  0.   0.45]
# Wakanda Forever [0.25 0.29 0.   0.46]
# Wakanda Forever [0.21 0.21 0.   0.58]
# Wakanda Forever [0.17 0.2  0.   0.63]
# Wakanda Forever [0.12 0.19 0.   0.69]
# Wakanda Forever [0.2 0.3 0.  0.5]
# Sad [0.31 0.48 0.01 0.2 ]
# Sad [0.32 0.48 0.01 0.19]
# Sad [0.32 0.54 0.05 0.09]
# Sad [0.3  0.41 0.12 0.17]
# Sad [0.29 0.42 0.12 0.17]
# Sad [0.25 0.46 0.11 0.18]
# Sad [0.28 0.43 0.12 0.17]
# Happy [0.36 0.33 0.13 0.18]
# Sad [0.33 0.37 0.13 0.17]
# Sad [0.29 0.39 0.14 0.18]
# Sad [0.31 0.33 0.15 0.21]
# Happy [0.32 0.31 0.15 0.22]
# Sad [0.3  0.33 0.15 0.22]
# Sad [0.27 0.34 0.15 0.24]
# Happy [0.29 0.27 0.16 0.28]
# Happy [0.3  0.3  0.15 0.25]
# Sad [0.25 0.33 0.14 0.28]
# Wakanda Forever [0.27 0.28 0.15 0.3 ]
# Sad [0.27 0.31 0.14 0.28]
# Sad [0.23 0.35 0.14 0.28]
# Wakanda Forever [0.19 0.33 0.14 0.34]
# Wakanda Forever [0.14 0.32 0.14 0.4 ]
# Wakanda Forever [0.11 0.27 0.13 0.49]
# Wakanda Forever [0.09 0.23 0.14 0.54]
# Wakanda Forever [0.11 0.2  0.14 0.55]
# Wakanda Forever [0.12 0.17 0.18 0.53]
# Wakanda Forever [0.13 0.15 0.22 0.5 ]
# Wakanda Forever [0.12 0.15 0.26 0.47]
# Wakanda Forever [0.11 0.17 0.26 0.46]
# Wakanda Forever [0.11 0.15 0.27 0.47]
# Wakanda Forever [0.12 0.14 0.29 0.45]
# Wakanda Forever [0.1  0.19 0.31 0.4 ]
# Wakanda Forever [0.11 0.18 0.35 0.36]
# Victorious [0.11 0.19 0.36 0.34]
# Victorious [0.11 0.13 0.38 0.38]
# Wakanda Forever [0.11 0.12 0.36 0.41]
# Wakanda Forever [0.11 0.14 0.34 0.41]
# Wakanda Forever [0.11 0.14 0.35 0.4 ]
# Wakanda Forever [0.11 0.14 0.35 0.4 ]
# Wakanda Forever [0.1  0.13 0.35 0.42]
# Wakanda Forever [0.1  0.12 0.35 0.43]
# Wakanda Forever [0.09 0.12 0.36 0.43]
# Wakanda Forever [0.07 0.12 0.36 0.45]
# Wakanda Forever [0.08 0.12 0.37 0.43]
# Wakanda Forever [0.07 0.13 0.35 0.45]
# Wakanda Forever [0.08 0.11 0.33 0.48]
# Wakanda Forever [0.07 0.15 0.35 0.43]
# Wakanda Forever [0.07 0.14 0.35 0.44]
# Wakanda Forever [0.06 0.12 0.33 0.49]
# Wakanda Forever [0.07 0.12 0.34 0.47]
# Wakanda Forever [0.06 0.11 0.32 0.51]
# Wakanda Forever [0.06 0.1  0.32 0.52]
# Wakanda Forever [0.07 0.1  0.3  0.53]
# Wakanda Forever [0.07 0.08 0.25 0.6 ]
# Wakanda Forever [0.08 0.08 0.24 0.6 ]
# Wakanda Forever [0.08 0.1  0.26 0.56]
# Wakanda Forever [0.06 0.13 0.29 0.52]
# Wakanda Forever [0.08 0.14 0.31 0.47]
# Wakanda Forever [0.07 0.13 0.33 0.47]
# Wakanda Forever [0.08 0.12 0.35 0.45]
# Wakanda Forever [0.08 0.12 0.35 0.45]
# Wakanda Forever [0.1  0.2  0.25 0.45]
# Sad [0.33 0.35 0.04 0.28]
# Happy [0.38 0.34 0.04 0.24]
# Happy [0.42 0.34 0.06 0.18]
# Happy [0.4  0.35 0.06 0.19]
# Happy [0.43 0.35 0.05 0.17]
# Happy [0.41 0.39 0.06 0.14]
# Happy [0.43 0.39 0.01 0.17]
# Sad [0.41 0.42 0.01 0.16]
# Happy [0.42 0.39 0.01 0.18]
# Happy [0.41 0.4  0.01 0.18]
# Happy [0.43 0.38 0.02 0.17]
# Happy [0.51 0.37 0.02 0.1 ]
# Happy [0.53 0.34 0.02 0.11]
# Happy [0.54 0.34 0.02 0.1 ]
# Happy [0.5  0.36 0.02 0.12]
# Happy [0.49 0.33 0.02 0.16]
# Happy [0.48 0.35 0.02 0.15]
# Happy [0.48 0.35 0.02 0.15]
# Happy [0.47 0.36 0.01 0.16]
# Happy [0.48 0.34 0.01 0.17]
# Happy [0.47 0.34 0.01 0.18]
# Happy [0.43 0.39 0.01 0.17]
# Happy [0.43 0.41 0.01 0.15]
# Sad [0.39 0.45 0.01 0.15]
# Happy [0.42 0.42 0.01 0.15]
# Sad [0.41 0.43 0.01 0.15]
# Sad [0.4  0.44 0.01 0.15]
# Happy [0.43 0.41 0.01 0.15]
# Sad [0.4  0.44 0.01 0.15]
# Sad [0.39 0.45 0.01 0.15]
# Sad [0.41 0.42 0.01 0.16]
# Sad [0.4  0.44 0.01 0.15]
# Happy [0.43 0.39 0.01 0.17]
# Happy [0.41 0.4  0.01 0.18]
# Happy [0.43 0.41 0.01 0.15]
# Happy [0.44 0.42 0.01 0.13]
# Happy [0.45 0.41 0.01 0.13]
# Happy [0.43 0.43 0.01 0.13]
# Happy [0.44 0.42 0.01 0.13]
# Happy [0.44 0.42 0.01 0.13]
# Sad [0.42 0.44 0.01 0.13]
# Happy [0.44 0.42 0.01 0.13]
# Happy [0.44 0.43 0.01 0.12]
# Happy [0.43 0.41 0.01 0.15]
# Sad [0.22 0.36 0.11 0.31]
# Sad [0.23 0.38 0.02 0.37]
# Wakanda Forever [0.2  0.31 0.12 0.37]
# Wakanda Forever [0.22 0.37 0.01 0.4 ]
# Wakanda Forever [0.19 0.38 0.02 0.41]
# Sad [0.16 0.41 0.02 0.41]
# Sad [0.14 0.44 0.02 0.4 ]
# Sad [0.09 0.49 0.02 0.4 ]
# Sad [0.09 0.48 0.02 0.41]
# Sad [0.11 0.43 0.05 0.41]
# Sad [0.11 0.44 0.05 0.4 ]
# Sad [0.11 0.43 0.05 0.41]
# Sad [0.1  0.44 0.05 0.41]
# Sad [0.09 0.45 0.05 0.41]
# Sad [0.1  0.44 0.05 0.41]
# Wakanda Forever [0.14 0.4  0.04 0.42]
# Sad [0.12 0.43 0.04 0.41]
# Sad [0.15 0.41 0.04 0.4 ]
# Sad [0.14 0.41 0.04 0.41]
# Wakanda Forever [0.16 0.38 0.04 0.42]
# Wakanda Forever [0.14 0.39 0.04 0.43]
# Wakanda Forever [0.15 0.38 0.04 0.43]
# Wakanda Forever [0.16 0.37 0.04 0.43]
# Sad [0.13 0.43 0.04 0.4 ]
# Sad [0.16 0.4  0.04 0.4 ]
# Wakanda Forever [0.16 0.38 0.04 0.42]
# Wakanda Forever [0.13 0.41 0.04 0.42]
# Wakanda Forever [0.14 0.4  0.04 0.42]
# Sad [0.09 0.49 0.04 0.38]
# Sad [0.05 0.5  0.18 0.27]
# Sad [0.09 0.44 0.17 0.3 ]
# Sad [0.13 0.41 0.16 0.3 ]
# Sad [0.13 0.41 0.16 0.3 ]
# Sad [0.14 0.39 0.16 0.31]
# Sad [0.13 0.41 0.16 0.3 ]
# Sad [0.09 0.45 0.17 0.29]
# Sad [0.1  0.43 0.18 0.29]
# Sad [0.08 0.45 0.21 0.26]
# Sad [0.07 0.45 0.22 0.26]
# Sad [0.07 0.39 0.27 0.27]
# Sad [0.08 0.41 0.27 0.24]
# Sad [0.09 0.38 0.35 0.18]
# Victorious [0.07 0.39 0.4  0.14]
# Sad [0.01 0.45 0.42 0.12]
# Victorious [0.07 0.29 0.52 0.12]
# Victorious [0.07 0.27 0.54 0.12]
# Victorious [0.06 0.29 0.52 0.13]
# Victorious [0.06 0.28 0.53 0.13]
# Victorious [0.05 0.27 0.56 0.12]
# Victorious [0.05 0.27 0.56 0.12]
# Victorious [0.06 0.26 0.58 0.1 ]
# Victorious [0.07 0.25 0.59 0.09]
# Victorious [0.07 0.25 0.59 0.09]
# Victorious [0.06 0.26 0.6  0.08]
# Victorious [0.07 0.26 0.6  0.07]
# Victorious [0.06 0.26 0.6  0.08]
# Victorious [0.07 0.27 0.59 0.07]
# Victorious [0.07 0.27 0.6  0.06]
# Victorious [0.09 0.25 0.6  0.06]
# Victorious [0.08 0.25 0.61 0.06]
# Victorious [0.09 0.25 0.6  0.06]
# Victorious [0.08 0.27 0.59 0.06]
# Victorious [0.07 0.3  0.56 0.07]
# Victorious [0.08 0.33 0.36 0.23]
# Sad [0.04 0.42 0.2  0.34]
# Sad [0.08 0.45 0.08 0.39]
# Wakanda Forever [0.11 0.41 0.06 0.42]
# Sad [0.11 0.42 0.06 0.41]
# Wakanda Forever [0.11 0.41 0.05 0.43]
# Sad [0.11 0.42 0.05 0.42]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Sad [0.11 0.43 0.04 0.42]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Wakanda Forever [0.11 0.41 0.04 0.44]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Sad [0.1  0.43 0.04 0.43]
# Sad [0.1  0.44 0.04 0.42]
# Sad [0.11 0.43 0.04 0.42]
# Sad [0.1  0.43 0.04 0.43]
# Sad [0.1  0.44 0.04 0.42]
# Sad [0.1  0.43 0.04 0.43]
# Sad [0.1  0.44 0.04 0.42]
# Sad [0.1  0.43 0.04 0.43]
# Wakanda Forever [0.1  0.42 0.04 0.44]
# Wakanda Forever [0.1  0.42 0.04 0.44]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Sad [0.1  0.43 0.04 0.43]
# Wakanda Forever [0.09 0.42 0.04 0.45]
# Sad [0.1  0.43 0.04 0.43]
# Wakanda Forever [0.11 0.38 0.04 0.47]
# Wakanda Forever [0.1  0.42 0.04 0.44]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Wakanda Forever [0.1  0.41 0.04 0.45]
# Wakanda Forever [0.1  0.41 0.04 0.45]
# Wakanda Forever [0.09 0.42 0.04 0.45]
# Wakanda Forever [0.09 0.42 0.04 0.45]
# Wakanda Forever [0.09 0.43 0.04 0.44]
# Wakanda Forever [0.08 0.43 0.04 0.45]
# Wakanda Forever [0.09 0.43 0.04 0.44]
# Wakanda Forever [0.09 0.42 0.04 0.45]
# Wakanda Forever [0.1  0.42 0.04 0.44]
# Sad [0.11 0.43 0.04 0.42]
# Wakanda Forever [0.11 0.42 0.04 0.43]
# Wakanda Forever [0.12 0.41 0.04 0.43]
# Wakanda Forever [0.11 0.39 0.04 0.46]
# Wakanda Forever [0.11 0.36 0.04 0.49]
# Wakanda Forever [0.11 0.4  0.04 0.45]
# Wakanda Forever [0.1  0.4  0.04 0.46]
# Wakanda Forever [0.11 0.4  0.04 0.45]
# Wakanda Forever [0.11 0.4  0.04 0.45]
# Wakanda Forever [0.11 0.39 0.04 0.46]
# Wakanda Forever [0.08 0.43 0.04 0.45]
# Sad [0.1  0.44 0.04 0.42]
# Sad [0.08 0.44 0.04 0.44]
# Wakanda Forever [0.08 0.43 0.04 0.45]
# Wakanda Forever [0.08 0.43 0.04 0.45]
# Sad [0.08 0.44 0.04 0.44]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.09 0.42 0.04 0.45]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Wakanda Forever [0.07 0.42 0.04 0.47]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.07 0.43 0.04 0.46]
# Wakanda Forever [0.07 0.41 0.04 0.48]
# Wakanda Forever [0.07 0.4  0.04 0.49]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.07 0.4  0.04 0.49]
# Wakanda Forever [0.1  0.41 0.04 0.45]
# Wakanda Forever [0.1  0.4  0.04 0.46]
# Sad [0.1  0.43 0.04 0.43]
# Wakanda Forever [0.1  0.41 0.04 0.45]
# Wakanda Forever [0.1  0.4  0.04 0.46]
# Wakanda Forever [0.11 0.38 0.04 0.47]
# Wakanda Forever [0.09 0.4  0.04 0.47]
# Wakanda Forever [0.08 0.4  0.04 0.48]
# Wakanda Forever [0.09 0.41 0.04 0.46]
# Wakanda Forever [0.07 0.42 0.04 0.47]
# Wakanda Forever [0.08 0.41 0.04 0.47]
# Wakanda Forever [0.12 0.39 0.04 0.45]
# Wakanda Forever [0.14 0.4  0.04 0.42]
# Sad [0.16 0.37 0.12 0.35]
# Happy [0.37 0.35 0.04 0.24]
# Happy [0.39 0.38 0.01 0.22]
# Happy [0.4  0.38 0.01 0.21]
# Happy [0.38 0.37 0.01 0.24]
# Happy [0.42 0.35 0.01 0.22]
# Happy [0.41 0.33 0.01 0.25]
# Happy [0.42 0.36 0.01 0.21]
# Sad [0.39 0.42 0.01 0.18]
# Sad [0.36 0.4  0.01 0.23]
# Sad [0.26 0.52 0.01 0.21]
# Sad [0.25 0.54 0.01 0.2 ]
# Sad [0.26 0.53 0.01 0.2 ]
# Sad [0.25 0.54 0.01 0.2 ]
# Sad [0.25 0.52 0.01 0.22]
# Sad [0.25 0.52 0.01 0.22]
# Sad [0.26 0.52 0.01 0.21]
# Sad [0.29 0.55 0.01 0.15]
# Sad [0.3  0.54 0.01 0.15]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.41 0.47 0.01 0.11]
# Sad [0.41 0.46 0.01 0.12]
# Sad [0.41 0.46 0.01 0.12]
# Sad [0.4  0.48 0.01 0.11]
# Sad [0.41 0.47 0.01 0.11]
# Sad [0.41 0.47 0.01 0.11]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.41 0.49 0.01 0.09]
# Sad [0.41 0.48 0.01 0.1 ]
# Sad [0.43 0.46 0.01 0.1 ]
# Sad [0.44 0.47 0.01 0.08]
# Happy [0.49 0.41 0.01 0.09]
# Happy [0.5  0.4  0.01 0.09]
# Happy [0.53 0.38 0.01 0.08]
# Happy [0.49 0.41 0.01 0.09]
# Happy [0.45 0.4  0.01 0.14]
# Happy [0.44 0.41 0.01 0.14]
# Happy [0.44 0.43 0.01 0.12]
# Happy [0.46 0.39 0.01 0.14]
# ...
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.14 0.25 0.   0.61]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.14 0.25 0.   0.61]
# Wakanda Forever [0.14 0.25 0.   0.61]
# Wakanda Forever [0.14 0.25 0.   0.61]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.12 0.27 0.   0.61]
# Wakanda Forever [0.12 0.26 0.   0.62]
# Wakanda Forever [0.12 0.26 0.   0.62]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.13 0.26 0.   0.61]
# Wakanda Forever [0.13 0.25 0.   0.62]
# Wakanda Forever [0.13 0.25 0.   0.62]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.27 0.   0.6 ]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.29 0.   0.58]
# Wakanda Forever [0.13 0.29 0.   0.58]
# Wakanda Forever [0.13 0.29 0.   0.58]
# Wakanda Forever [0.13 0.29 0.   0.58]
# Wakanda Forever [0.13 0.29 0.   0.58]
# Wakanda Forever [0.13 0.29 0.   0.58]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.13 0.28 0.   0.59]
# Wakanda Forever [0.12 0.26 0.   0.62]
# Wakanda Forever [0.11 0.23 0.   0.66]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.11 0.23 0.   0.66]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.11 0.23 0.   0.66]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.11 0.23 0.   0.66]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.12 0.23 0.   0.65]
# Wakanda Forever [0.11 0.22 0.   0.67]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.12 0.22 0.   0.66]
# Wakanda Forever [0.11 0.24 0.   0.65]
# Wakanda Forever [0.08 0.27 0.   0.65]
# Wakanda Forever [0.1  0.27 0.   0.63]
# Wakanda Forever [0.11 0.25 0.   0.64]
# Wakanda Forever [0.11 0.25 0.   0.64]
# Wakanda Forever [0.11 0.25 0.   0.64]
# Wakanda Forever [0.1  0.28 0.   0.62]
# Wakanda Forever [0.1  0.27 0.   0.63]
# Wakanda Forever [0.1  0.28 0.   0.62]
# Wakanda Forever [0.05 0.34 0.   0.61]
# Wakanda Forever [0.05 0.37 0.   0.58]
# Wakanda Forever [0.05 0.39 0.   0.56]
# Wakanda Forever [0.05 0.37 0.   0.58]
# Wakanda Forever [0.04 0.36 0.   0.6 ]
# Wakanda Forever [0.1  0.25 0.   0.65]
# Wakanda Forever [0.07 0.14 0.   0.79]
# Wakanda Forever [0.05 0.08 0.   0.87]
# Wakanda Forever [0.27 0.34 0.   0.39]
# Sad [0.31 0.43 0.01 0.25]
# Sad [0.32 0.48 0.01 0.19]
# Sad [0.3  0.52 0.01 0.17]
# Sad [0.29 0.54 0.01 0.16]
# Sad [0.25 0.49 0.09 0.17]
# Sad [0.19 0.42 0.14 0.25]
# Sad [0.21 0.44 0.12 0.23]
# Sad [0.23 0.44 0.09 0.24]
# Sad [0.24 0.55 0.01 0.2 ]
# Sad [0.22 0.6  0.   0.18]
# Sad [0.2  0.63 0.   0.17]
# Sad [0.18 0.59 0.01 0.22]
# Sad [0.19 0.58 0.01 0.22]
# Sad [0.27 0.49 0.01 0.23]
# Sad [0.28 0.49 0.01 0.22]
# Sad [0.27 0.46 0.   0.27]
# Wakanda Forever [0.22 0.36 0.   0.42]
# Sad [0.25 0.44 0.   0.31]
# Wakanda Forever [0.2  0.36 0.   0.44]
# Wakanda Forever [0.2  0.35 0.   0.45]
# Wakanda Forever [0.18 0.31 0.   0.51]
# Wakanda Forever [0.18 0.24 0.   0.58]
# Wakanda Forever [0.18 0.26 0.   0.56]
# Wakanda Forever [0.19 0.22 0.   0.59]
# Wakanda Forever [0.2  0.18 0.   0.62]
# Wakanda Forever [0.19 0.19 0.   0.62]
# Wakanda Forever [0.17 0.24 0.   0.59]
# Wakanda Forever [0.18 0.26 0.   0.56]
# Wakanda Forever [0.18 0.19 0.   0.63]
# Wakanda Forever [0.18 0.15 0.   0.67]
# Wakanda Forever [0.17 0.15 0.   0.68]
# Wakanda Forever [0.17 0.15 0.   0.68]
# Wakanda Forever [0.21 0.23 0.   0.56]
# Wakanda Forever [0.2  0.27 0.   0.53]
# Wakanda Forever [0.17 0.26 0.   0.57]
# Sad [0.31 0.37 0.   0.32]
# Sad [0.36 0.47 0.   0.17]
# Sad [0.35 0.52 0.01 0.12]
# Sad [0.35 0.54 0.01 0.1 ]
# Sad [0.32 0.58 0.01 0.09]
# Sad [0.32 0.58 0.01 0.09]
# Sad [0.32 0.57 0.01 0.1 ]
# Sad [0.32 0.57 0.01 0.1 ]
# Sad [0.32 0.56 0.01 0.11]
# Sad [0.34 0.54 0.01 0.11]
# Sad [0.33 0.56 0.01 0.1 ]
# Sad [0.37 0.5  0.01 0.12]
# Sad [0.41 0.46 0.01 0.12]
# Sad [0.4  0.47 0.01 0.12]
# Sad [0.35 0.53 0.01 0.11]
# Sad [0.35 0.53 0.01 0.11]
# Sad [0.4  0.44 0.   0.16]
# Sad [0.33 0.5  0.01 0.16]
# Sad [0.36 0.46 0.   0.18]
# Sad [0.36 0.41 0.   0.23]
# Sad [0.3  0.41 0.   0.29]
# Sad [0.28 0.39 0.   0.33]
# Sad [0.3  0.36 0.   0.34]
# Wakanda Forever [0.28 0.32 0.   0.4 ]
# Wakanda Forever [0.24 0.33 0.   0.43]
# Wakanda Forever [0.28 0.33 0.   0.39]
# Wakanda Forever [0.26 0.34 0.   0.4 ]
# Sad [0.33 0.37 0.   0.3 ]
# Wakanda Forever [0.31 0.34 0.   0.35]
# Wakanda Forever [0.3  0.34 0.   0.36]
# Wakanda Forever [0.22 0.38 0.   0.4 ]
# Wakanda Forever [0.21 0.34 0.   0.45]
# Wakanda Forever [0.21 0.35 0.   0.44]
# Wakanda Forever [0.16 0.33 0.   0.51]
# Wakanda Forever [0.17 0.34 0.   0.49]
# Wakanda Forever [0.13 0.33 0.   0.54]
# Wakanda Forever [0.14 0.32 0.   0.54]
# Wakanda Forever [0.17 0.32 0.   0.51]
# Wakanda Forever [0.22 0.37 0.   0.41]
# Sad [0.31 0.39 0.   0.3 ]
# Sad [0.34 0.37 0.   0.29]
# Sad [0.35 0.4  0.   0.25]
# Sad [0.31 0.38 0.   0.31]
# Sad [0.32 0.41 0.   0.27]
# Sad [0.33 0.41 0.   0.26]
# Sad [0.34 0.48 0.   0.18]
# Sad [0.38 0.4  0.   0.22]
# Sad [0.35 0.39 0.   0.26]
# Sad [0.3  0.49 0.   0.21]
# Sad [0.3  0.54 0.   0.16]
# Sad [0.29 0.54 0.   0.17]
# Sad [0.31 0.53 0.01 0.15]
# Sad [0.31 0.52 0.   0.17]
# Sad [0.29 0.54 0.   0.17]
# Sad [0.3  0.54 0.   0.16]
# Sad [0.31 0.53 0.   0.16]
# Sad [0.31 0.53 0.   0.16]
# Sad [0.3  0.52 0.   0.18]
# Sad [0.29 0.51 0.   0.2 ]
# Sad [0.31 0.5  0.   0.19]
# Sad [0.3  0.51 0.   0.19]
# Sad [0.29 0.49 0.   0.22]
# Sad [0.29 0.49 0.   0.22]
# Sad [0.29 0.49 0.   0.22]
# Sad [0.3  0.46 0.   0.24]
# Sad [0.33 0.47 0.   0.2 ]
# Sad [0.29 0.48 0.03 0.2 ]
# Sad [0.3 0.5 0.  0.2]
# Sad [0.2  0.44 0.14 0.22]
# Sad [0.1  0.49 0.14 0.27]
# Sad [0.09 0.55 0.14 0.22]
# Sad [0.04 0.59 0.14 0.23]
# Sad [0.07 0.57 0.15 0.21]
# Sad [0.06 0.57 0.15 0.22]
# Sad [0.07 0.54 0.18 0.21]
# Sad [0.07 0.52 0.18 0.23]
# Sad [0.06 0.52 0.18 0.24]
# Sad [0.08 0.5  0.21 0.21]
# Sad [0.08 0.47 0.23 0.22]
# Sad [0.09 0.46 0.23 0.22]
# Sad [0.06 0.42 0.3  0.22]
# Sad [0.05 0.41 0.3  0.24]
# Sad [0.04 0.38 0.33 0.25]
# Sad [0.05 0.38 0.35 0.22]
# Victorious [0.05 0.36 0.38 0.21]
# Victorious [0.04 0.35 0.41 0.2 ]
# Victorious [0.04 0.34 0.41 0.21]
# Victorious [0.04 0.31 0.49 0.16]
# Victorious [0.04 0.29 0.48 0.19]
# Victorious [0.02 0.3  0.53 0.15]
# Victorious [0.02 0.3  0.54 0.14]
# Victorious [0.02 0.29 0.54 0.15]
# Victorious [0.02 0.3  0.54 0.14]
# Victorious [0.02 0.28 0.57 0.13]
# Victorious [0.02 0.27 0.6  0.11]
# Victorious [0.02 0.27 0.61 0.1 ]
# Victorious [0.02 0.26 0.62 0.1 ]
# Victorious [0.02 0.26 0.62 0.1 ]
# Victorious [0.02 0.26 0.62 0.1 ]
# Victorious [0.02 0.25 0.62 0.11]
# Victorious [0.02 0.27 0.62 0.09]
# Victorious [0.02 0.27 0.62 0.09]
# Victorious [0.02 0.26 0.63 0.09]
# Victorious [0.02 0.24 0.64 0.1 ]
# Victorious [0.03 0.23 0.64 0.1 ]
# Victorious [0.03 0.23 0.64 0.1 ]
# Victorious [0.04 0.22 0.64 0.1 ]
# Victorious [0.04 0.22 0.64 0.1 ]
# Victorious [0.03 0.34 0.51 0.12]
# Sad [0.03 0.45 0.29 0.23]
# Wakanda Forever [0.04 0.39 0.15 0.42]
# Wakanda Forever [0.04 0.4  0.15 0.41]
# Wakanda Forever [0.04 0.39 0.11 0.46]
# Sad [0.05 0.45 0.06 0.44]
# Sad [0.04 0.46 0.04 0.46]
# Wakanda Forever [0.04 0.45 0.04 0.47]
# Wakanda Forever [0.05 0.45 0.04 0.46]
# Wakanda Forever [0.05 0.45 0.04 0.46]
# Wakanda Forever [0.05 0.45 0.04 0.46]
# Wakanda Forever [0.05 0.45 0.04 0.46]
# Wakanda Forever [0.06 0.4  0.09 0.45]
# Wakanda Forever [0.06 0.42 0.08 0.44]
# Wakanda Forever [0.04 0.39 0.15 0.42]
# Wakanda Forever [0.04 0.39 0.15 0.42]
# Wakanda Forever [0.05 0.41 0.05 0.49]
# Wakanda Forever [0.04 0.42 0.05 0.49]
# Wakanda Forever [0.04 0.42 0.04 0.5 ]
# Wakanda Forever [0.05 0.42 0.04 0.49]
# Wakanda Forever [0.05 0.43 0.04 0.48]
# Wakanda Forever [0.04 0.43 0.04 0.49]
# Wakanda Forever [0.05 0.41 0.04 0.5 ]
# Wakanda Forever [0.04 0.43 0.04 0.49]
# Wakanda Forever [0.04 0.44 0.04 0.48]
# Wakanda Forever [0.05 0.43 0.04 0.48]
# Wakanda Forever [0.04 0.44 0.04 0.48]
# Wakanda Forever [0.05 0.42 0.04 0.49]
# Wakanda Forever [0.04 0.44 0.04 0.48]
# Sad [0.   0.55 0.04 0.41]
# Sad [0.   0.57 0.04 0.39]
# Sad [0.   0.69 0.03 0.28]
# Sad [0.06 0.72 0.03 0.19]
# Sad [0.09 0.69 0.03 0.19]
# Sad [0.17 0.63 0.   0.2 ]
# Sad [0.21 0.55 0.   0.24]
# Sad [0.2  0.58 0.   0.22]
# Sad [0.18 0.6  0.01 0.21]
# Sad [0.12 0.64 0.02 0.22]
# Sad [0.16 0.62 0.   0.22]
# Sad [0.19 0.58 0.   0.23]
# Sad [0.2  0.55 0.01 0.24]
# Sad [0.2  0.55 0.01 0.24]
# Sad [0.21 0.55 0.01 0.23]
# Sad [0.19 0.57 0.01 0.23]
# Sad [0.19 0.57 0.01 0.23]
# Sad [0.21 0.56 0.01 0.22]
# Sad [0.19 0.59 0.01 0.21]
# Sad [0.22 0.58 0.01 0.19]
# Sad [0.24 0.57 0.01 0.18]
# Sad [0.21 0.61 0.   0.18]
# Sad [0.22 0.61 0.01 0.16]
# Happy [0.45 0.39 0.01 0.15]
# Sad [0.42 0.47 0.01 0.1 ]
# Sad [0.4  0.49 0.01 0.1 ]
# Sad [0.41 0.48 0.01 0.1 ]
# Sad [0.43 0.44 0.01 0.12]
# Sad [0.43 0.44 0.01 0.12]
# Happy [0.44 0.43 0.01 0.12]
# Happy [0.44 0.43 0.01 0.12]
# Happy [0.45 0.43 0.01 0.11]
# Happy [0.45 0.43 0.01 0.11]
# Happy [0.45 0.44 0.01 0.1 ]
# Happy [0.47 0.44 0.01 0.08]
# Happy [0.44 0.44 0.01 0.11]
# Sad [0.43 0.45 0.01 0.11]
# Sad [0.42 0.46 0.01 0.11]
# Sad [0.43 0.45 0.01 0.11]
# Happy [0.43 0.43 0.01 0.13]
# Sad [0.43 0.45 0.01 0.11]
# Sad [0.44 0.45 0.01 0.1 ]
# Happy [0.45 0.44 0.01 0.1 ]
# Happy [0.45 0.45 0.01 0.09]
# Happy [0.46 0.45 0.01 0.08]
# Happy [0.47 0.45 0.01 0.07]
# Happy [0.46 0.44 0.01 0.09]
# Happy [0.46 0.45 0.01 0.08]
# Sad [0.43 0.46 0.01 0.1 ]
# Happy [0.46 0.46 0.01 0.07]
# Sad [0.45 0.46 0.01 0.08]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.43 0.46 0.01 0.1 ]
# Sad [0.44 0.47 0.01 0.08]
# Sad [0.43 0.47 0.01 0.09]
# Sad [0.45 0.46 0.01 0.08]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.44 0.47 0.01 0.08]
# Sad [0.43 0.47 0.01 0.09]
# Happy [0.46 0.46 0.01 0.07]
# Happy [0.46 0.46 0.01 0.07]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.44 0.47 0.01 0.08]
# Sad [0.44 0.47 0.01 0.08]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.45 0.46 0.01 0.08]
# Sad [0.46 0.47 0.01 0.06]
# Sad [0.45 0.46 0.01 0.08]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.44 0.45 0.01 0.1 ]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.44 0.45 0.01 0.1 ]
# Sad [0.44 0.45 0.01 0.1 ]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.44 0.46 0.01 0.09]
# Sad [0.37 0.53 0.01 0.09]
# Sad [0.35 0.54 0.01 0.1 ]
# Sad [0.37 0.53 0.01 0.09]
# Sad [0.34 0.56 0.01 0.09]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.33 0.57 0.01 0.09]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.32 0.59 0.01 0.08]
# Sad [0.3  0.6  0.01 0.09]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.31 0.6  0.01 0.08]
# Sad [0.31 0.61 0.01 0.07]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.29 0.62 0.01 0.08]
# Sad [0.3  0.63 0.01 0.06]
# Sad [0.29 0.63 0.01 0.07]
# Sad [0.36 0.56 0.01 0.07]
# Sad [0.36 0.55 0.01 0.08]
# Sad [0.33 0.61 0.01 0.05]
# Sad [0.33 0.59 0.01 0.07]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.32 0.59 0.01 0.08]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.32 0.58 0.01 0.09]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.32 0.57 0.01 0.1 ]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.34 0.56 0.01 0.09]
# Sad [0.36 0.57 0.01 0.06]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.37 0.53 0.01 0.09]
# Sad [0.37 0.55 0.01 0.07]
# Sad [0.33 0.59 0.01 0.07]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.37 0.55 0.01 0.07]
# Sad [0.35 0.57 0.01 0.07]
# Sad [0.37 0.53 0.01 0.09]
# Sad [0.35 0.57 0.01 0.07]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.37 0.54 0.01 0.08]
# Sad [0.37 0.55 0.01 0.07]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.3  0.6  0.01 0.09]
# Sad [0.32 0.59 0.01 0.08]
# Sad [0.32 0.59 0.01 0.08]
# Sad [0.35 0.57 0.01 0.07]
# Sad [0.35 0.57 0.01 0.07]
# Sad [0.36 0.57 0.01 0.06]
# Sad [0.37 0.56 0.01 0.06]
# Sad [0.36 0.57 0.01 0.06]
# Sad [0.35 0.56 0.01 0.08]
# Sad [0.36 0.56 0.01 0.07]
# Sad [0.27 0.69 0.01 0.03]
# Sad [0.34 0.56 0.01 0.09]
# Sad [0.35 0.55 0.01 0.09]
# Sad [0.38 0.51 0.01 0.1 ]
# Sad [0.37 0.45 0.   0.18]
# Sad [0.35 0.49 0.   0.16]
# Sad [0.36 0.43 0.   0.21]
# Sad [0.34 0.43 0.   0.23]
# Sad [0.33 0.41 0.   0.26]
# Sad [0.3 0.4 0.  0.3]
# Sad [0.31 0.4  0.   0.29]
# Sad [0.3 0.4 0.  0.3]
# Sad [0.29 0.41 0.   0.3 ]
# Sad [0.29 0.4  0.   0.31]
# Sad [0.29 0.41 0.   0.3 ]
# Sad [0.3 0.4 0.  0.3]
# Sad [0.28 0.4  0.   0.32]
# Sad [0.28 0.41 0.   0.31]
# Sad [0.28 0.38 0.   0.34]
# Sad [0.27 0.38 0.   0.35]
# Wakanda Forever [0.24 0.36 0.   0.4 ]
# Wakanda Forever [0.17 0.31 0.   0.52]
# Wakanda Forever [0.18 0.33 0.   0.49]
# Wakanda Forever [0.18 0.34 0.   0.48]
# Wakanda Forever [0.17 0.33 0.   0.5 ]
# Wakanda Forever [0.18 0.33 0.   0.49]
# Wakanda Forever [0.17 0.33 0.   0.5 ]
# Wakanda Forever [0.18 0.33 0.   0.49]
# Wakanda Forever [0.17 0.33 0.   0.5 ]
# Wakanda Forever [0.18 0.34 0.   0.48]
# Wakanda Forever [0.18 0.33 0.   0.49]
# Wakanda Forever [0.19 0.34 0.   0.47]
# Wakanda Forever [0.2  0.36 0.   0.44]
# Wakanda Forever [0.19 0.35 0.   0.46]
# Wakanda Forever [0.2  0.34 0.   0.46]
# Wakanda Forever [0.2  0.34 0.   0.46]
# Wakanda Forever [0.2  0.35 0.   0.45]
# Wakanda Forever [0.2  0.34 0.   0.46]
# Wakanda Forever [0.24 0.36 0.   0.4 ]
# Sad [0.28 0.39 0.   0.33]
# Sad [0.28 0.36 0.   0.36]
# Sad [0.27 0.37 0.   0.36]
# Sad [0.27 0.38 0.   0.35]
# Sad [0.27 0.38 0.   0.35]
# Sad [0.31 0.38 0.   0.31]
# Sad [0.32 0.38 0.   0.3 ]
# Sad [0.32 0.4  0.   0.28]
# Sad [0.28 0.38 0.   0.34]
# Sad [0.33 0.42 0.   0.25]
# Sad [0.36 0.44 0.   0.2 ]
# Sad [0.37 0.47 0.   0.16]
# Sad [0.32 0.57 0.01 0.1 ]
# Sad [0.31 0.59 0.01 0.09]
# Sad [0.31 0.59 0.01 0.09]
# Sad [0.32 0.57 0.01 0.1 ]
# Sad [0.3  0.6  0.01 0.09]
# Sad [0.31 0.58 0.01 0.1 ]
# Sad [0.3  0.61 0.01 0.08]
# Sad [0.23 0.48 0.07 0.22]
# Wakanda Forever [0.16 0.26 0.1  0.48]
# Wakanda Forever [0.16 0.26 0.09 0.49]
# Wakanda Forever [0.14 0.23 0.11 0.52]
# Wakanda Forever [0.13 0.22 0.09 0.56]
# Wakanda Forever [0.11 0.24 0.1  0.55]
# Wakanda Forever [0.12 0.22 0.1  0.56]
# Wakanda Forever [0.13 0.22 0.1  0.55]
# Wakanda Forever [0.12 0.22 0.1  0.56]
# Wakanda Forever [0.13 0.23 0.09 0.55]
# Wakanda Forever [0.11 0.25 0.1  0.54]
# Wakanda Forever [0.18 0.28 0.1  0.44]
# Sad [0.18 0.39 0.08 0.35]
# Sad [0.2  0.41 0.07 0.32]
# Sad [0.21 0.47 0.05 0.27]
# Sad [0.2  0.44 0.08 0.28]
# Sad [0.21 0.47 0.06 0.26]
# Sad [0.23 0.49 0.05 0.23]
# Sad [0.24 0.49 0.06 0.21]
# Sad [0.25 0.52 0.05 0.18]
# Sad [0.25 0.49 0.06 0.2 ]
# Sad [0.28 0.5  0.04 0.18]
# Sad [0.26 0.52 0.04 0.18]
# Sad [0.27 0.61 0.01 0.11]
# Sad [0.25 0.63 0.01 0.11]
# Sad [0.32 0.57 0.01 0.1 ]
# Sad [0.32 0.58 0.01 0.09]
# Sad [0.34 0.56 0.01 0.09]
# Sad [0.35 0.54 0.01 0.1 ]
# Sad [0.36 0.53 0.01 0.1 ]
# Sad [0.33 0.57 0.01 0.09]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.33 0.58 0.01 0.08]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.36 0.54 0.01 0.09]
# Sad [0.35 0.5  0.   0.15]
# Sad [0.31 0.5  0.   0.19]
# Sad [0.35 0.51 0.   0.14]
# Sad [0.35 0.54 0.01 0.1 ]
# Sad [0.3  0.6  0.01 0.09]
# Sad [0.35 0.48 0.   0.17]
# Sad [0.38 0.51 0.01 0.1 ]
# Sad [0.39 0.49 0.   0.12]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [1280,720]).astype(int))
# Out:
# (425, 203)
